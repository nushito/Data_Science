# %%
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Tidying and Cleaning Lab
# ## Reading, tidying and cleaning data. Preparing data for exploration, mining, analysis and learning

# %% [markdown]
# In this lab, you'll be working with the Coffee Quality Index dataset, located [here](https://www.kaggle.com/datasets/volpatto/coffee-quality-database-from-cqi). For convenience (and to save trouble in case you can't download files, or someone uploads a newer version), I've provided the dataset in the `data/` folder. The metadata (description) is at the Kaggle link. For this lab, you'll only need `merged_data_cleaned.csv`, as it is the concatenation of the other two datasets.
#
# In this (and the following labs), you'll get several questions and problems. Do your analysis, describe it, use any tools and plots you wish, and answer. You can create any amount of cells you'd like.
#
# Sometimes, the answers will not be unique, and they will depend on how you decide to approach and solve the problem. This is usual - we're doing science after all!
#
# It's a good idea to save your clean dataset after all the work you've done to it.

# %% [markdown]
# ### Problem 1. Read the dataset (1 point)
# This should be self-explanatory. The first column is the index.

# %%
coffee_set = pd.read_csv("data/merged_data_cleaned.csv")
coffee_set.shape
# Out:
# (1339, 44)

# %%
coffee_set.head()
# Out:
#    Unnamed: 0  Species                     Owner Country.of.Origin  \
# 0           0  Arabica                 metad plc          Ethiopia
# 1           1  Arabica                 metad plc          Ethiopia
# 2           2  Arabica  grounds for health admin         Guatemala
# 3           3  Arabica       yidnekachew dabessa          Ethiopia
# 4           4  Arabica                 metad plc          Ethiopia
#
#                                   Farm.Name Lot.Number       Mill ICO.Number  \
# 0                                 metad plc        NaN  metad plc  2014/2015
# 1                                 metad plc        NaN  metad plc  2014/2015
# 2  san marcos barrancas "san cristobal cuch        NaN        NaN        NaN
# 3     yidnekachew dabessa coffee plantation        NaN    wolensu        NaN
# 4                                 metad plc        NaN  metad plc  2014/2015
#
#                                  Company       Altitude  ...  Color  \
# 0      metad agricultural developmet plc      1950-2200  ...  Green
# 1      metad agricultural developmet plc      1950-2200  ...  Green
# 2                                    NaN  1600 - 1800 m  ...    NaN
# 3  yidnekachew debessa coffee plantation      1800-2200  ...  Green
# 4      metad agricultural developmet plc      1950-2200  ...  Green
#
#   Category.Two.Defects        Expiration                  Certification.Body  \
# 0                    0   April 3rd, 2016  METAD Agricultural Development plc
# 1                    1   April 3rd, 2016  METAD Agricultural Development plc
# 2                    0    May 31st, 2011        Specialty Coffee Association
# 3                    2  March 25th, 2016  METAD Agricultural Development plc
# 4                    2   April 3rd, 2016  METAD Agricultural Development plc
#
#                       Certification.Address  \
# 0  309fcf77415a3661ae83e027f7e5f05dad786e44
# 1  309fcf77415a3661ae83e027f7e5f05dad786e44
# 2  36d0d00a3724338ba7937c52a378d085f2172daa
# 3  309fcf77415a3661ae83e027f7e5f05dad786e44
# 4  309fcf77415a3661ae83e027f7e5f05dad786e44
#
#                       Certification.Contact unit_of_measurement  \
# 0  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 1  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 2  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 3  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 4  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
#
#   altitude_low_meters altitude_high_meters altitude_mean_meters
# 0              1950.0               2200.0               2075.0
# 1              1950.0               2200.0               2075.0
# 2              1600.0               1800.0               1700.0
# 3              1800.0               2200.0               2000.0
# 4              1950.0               2200.0               2075.0
#
# [5 rows x 44 columns]

# %%
coffee_set = coffee_set.drop(["Unnamed: 0"], axis = 1)

# %%
coffee_set.head()
# Out:
#    Species                     Owner Country.of.Origin  \
# 0  Arabica                 metad plc          Ethiopia
# 1  Arabica                 metad plc          Ethiopia
# 2  Arabica  grounds for health admin         Guatemala
# 3  Arabica       yidnekachew dabessa          Ethiopia
# 4  Arabica                 metad plc          Ethiopia
#
#                                   Farm.Name Lot.Number       Mill ICO.Number  \
# 0                                 metad plc        NaN  metad plc  2014/2015
# 1                                 metad plc        NaN  metad plc  2014/2015
# 2  san marcos barrancas "san cristobal cuch        NaN        NaN        NaN
# 3     yidnekachew dabessa coffee plantation        NaN    wolensu        NaN
# 4                                 metad plc        NaN  metad plc  2014/2015
#
#                                  Company       Altitude        Region  ...  \
# 0      metad agricultural developmet plc      1950-2200  guji-hambela  ...
# 1      metad agricultural developmet plc      1950-2200  guji-hambela  ...
# 2                                    NaN  1600 - 1800 m           NaN  ...
# 3  yidnekachew debessa coffee plantation      1800-2200        oromia  ...
# 4      metad agricultural developmet plc      1950-2200  guji-hambela  ...
#
#    Color  Category.Two.Defects        Expiration  \
# 0  Green                     0   April 3rd, 2016
# 1  Green                     1   April 3rd, 2016
# 2    NaN                     0    May 31st, 2011
# 3  Green                     2  March 25th, 2016
# 4  Green                     2   April 3rd, 2016
#
#                    Certification.Body  \
# 0  METAD Agricultural Development plc
# 1  METAD Agricultural Development plc
# 2        Specialty Coffee Association
# 3  METAD Agricultural Development plc
# 4  METAD Agricultural Development plc
#
#                       Certification.Address  \
# 0  309fcf77415a3661ae83e027f7e5f05dad786e44
# 1  309fcf77415a3661ae83e027f7e5f05dad786e44
# 2  36d0d00a3724338ba7937c52a378d085f2172daa
# 3  309fcf77415a3661ae83e027f7e5f05dad786e44
# 4  309fcf77415a3661ae83e027f7e5f05dad786e44
#
#                       Certification.Contact unit_of_measurement  \
# 0  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 1  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 2  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 3  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 4  19fef5a731de2db57d16da10287413f5f99bc2dd                   m
#
#   altitude_low_meters altitude_high_meters  altitude_mean_meters
# 0              1950.0               2200.0                2075.0
# 1              1950.0               2200.0                2075.0
# 2              1600.0               1800.0                1700.0
# 3              1800.0               2200.0                2000.0
# 4              1950.0               2200.0                2075.0
#
# [5 rows x 43 columns]

# %%
pd.read_csv("data/merged_data_cleaned.csv", index_col = 0)
# Out:
#       Species                     Owner Country.of.Origin  \
# 0     Arabica                 metad plc          Ethiopia
# 1     Arabica                 metad plc          Ethiopia
# 2     Arabica  grounds for health admin         Guatemala
# 3     Arabica       yidnekachew dabessa          Ethiopia
# 4     Arabica                 metad plc          Ethiopia
# ...       ...                       ...               ...
# 1334  Robusta               luis robles           Ecuador
# 1335  Robusta               luis robles           Ecuador
# 1336  Robusta               james moore     United States
# 1337  Robusta             cafe politico             India
# 1338  Robusta             cafe politico           Vietnam
#
#                                      Farm.Name Lot.Number            Mill  \
# 0                                    metad plc        NaN       metad plc
# 1                                    metad plc        NaN       metad plc
# 2     san marcos barrancas "san cristobal cuch        NaN             NaN
# 3        yidnekachew dabessa coffee plantation        NaN         wolensu
# 4                                    metad plc        NaN       metad plc
# ...                                        ...        ...             ...
# 1334                                 robustasa   Lavado 1     our own lab
# 1335                                 robustasa   Lavado 3  own laboratory
# 1336                           fazenda cazengo        NaN    cafe cazengo
# 1337                                       NaN        NaN             NaN
# 1338                                       NaN        NaN             NaN
#
#              ICO.Number                                Company       Altitude  \
# 0             2014/2015      metad agricultural developmet plc      1950-2200
# 1             2014/2015      metad agricultural developmet plc      1950-2200
# 2                   NaN                                    NaN  1600 - 1800 m
# 3                   NaN  yidnekachew debessa coffee plantation      1800-2200
# 4             2014/2015      metad agricultural developmet plc      1950-2200
# ...                 ...                                    ...            ...
# 1334                NaN                              robustasa            NaN
# 1335                NaN                              robustasa             40
# 1336                NaN                global opportunity fund     795 meters
# 1337  14-1118-2014-0087                          cafe politico            NaN
# 1338                NaN                          cafe politico            NaN
#
#                              Region  ...       Color  Category.Two.Defects  \
# 0                      guji-hambela  ...       Green                     0
# 1                      guji-hambela  ...       Green                     1
# 2                               NaN  ...         NaN                     0
# 3                            oromia  ...       Green                     2
# 4                      guji-hambela  ...       Green                     2
# ...                             ...  ...         ...                   ...
# 1334               san juan, playas  ...  Blue-Green                     1
# 1335               san juan, playas  ...  Blue-Green                     0
# 1336  kwanza norte province, angola  ...         NaN                     6
# 1337                            NaN  ...       Green                     1
# 1338                            NaN  ...         NaN                     9
#
#                Expiration                  Certification.Body  \
# 0         April 3rd, 2016  METAD Agricultural Development plc
# 1         April 3rd, 2016  METAD Agricultural Development plc
# 2          May 31st, 2011        Specialty Coffee Association
# 3        March 25th, 2016  METAD Agricultural Development plc
# 4         April 3rd, 2016  METAD Agricultural Development plc
# ...                   ...                                 ...
# 1334   January 18th, 2017        Specialty Coffee Association
# 1335   January 18th, 2017        Specialty Coffee Association
# 1336  December 23rd, 2015        Specialty Coffee Association
# 1337    August 25th, 2015        Specialty Coffee Association
# 1338    August 25th, 2015        Specialty Coffee Association
#
#                          Certification.Address  \
# 0     309fcf77415a3661ae83e027f7e5f05dad786e44
# 1     309fcf77415a3661ae83e027f7e5f05dad786e44
# 2     36d0d00a3724338ba7937c52a378d085f2172daa
# 3     309fcf77415a3661ae83e027f7e5f05dad786e44
# 4     309fcf77415a3661ae83e027f7e5f05dad786e44
# ...                                        ...
# 1334  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1335  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1336  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1337  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1338  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
#
#                          Certification.Contact unit_of_measurement  \
# 0     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 1     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 2     0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 3     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 4     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# ...                                        ...                 ...
# 1334  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1335  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1336  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1337  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1338  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
#
#      altitude_low_meters altitude_high_meters  altitude_mean_meters
# 0                 1950.0               2200.0                2075.0
# 1                 1950.0               2200.0                2075.0
# 2                 1600.0               1800.0                1700.0
# 3                 1800.0               2200.0                2000.0
# 4                 1950.0               2200.0                2075.0
# ...                  ...                  ...                   ...
# 1334                 NaN                  NaN                   NaN
# 1335                40.0                 40.0                  40.0
# 1336               795.0                795.0                 795.0
# 1337                 NaN                  NaN                   NaN
# 1338                 NaN                  NaN                   NaN
#
# [1339 rows x 43 columns]

# %%
coffee = pd.read_csv("data/merged_data_cleaned.csv")
coffee
# Out:
#       Unnamed: 0  Species                     Owner Country.of.Origin  \
# 0              0  Arabica                 metad plc          Ethiopia
# 1              1  Arabica                 metad plc          Ethiopia
# 2              2  Arabica  grounds for health admin         Guatemala
# 3              3  Arabica       yidnekachew dabessa          Ethiopia
# 4              4  Arabica                 metad plc          Ethiopia
# ...          ...      ...                       ...               ...
# 1334        1334  Robusta               luis robles           Ecuador
# 1335        1335  Robusta               luis robles           Ecuador
# 1336        1336  Robusta               james moore     United States
# 1337        1337  Robusta             cafe politico             India
# 1338        1338  Robusta             cafe politico           Vietnam
#
#                                      Farm.Name Lot.Number            Mill  \
# 0                                    metad plc        NaN       metad plc
# 1                                    metad plc        NaN       metad plc
# 2     san marcos barrancas "san cristobal cuch        NaN             NaN
# 3        yidnekachew dabessa coffee plantation        NaN         wolensu
# 4                                    metad plc        NaN       metad plc
# ...                                        ...        ...             ...
# 1334                                 robustasa   Lavado 1     our own lab
# 1335                                 robustasa   Lavado 3  own laboratory
# 1336                           fazenda cazengo        NaN    cafe cazengo
# 1337                                       NaN        NaN             NaN
# 1338                                       NaN        NaN             NaN
#
#              ICO.Number                                Company       Altitude  \
# 0             2014/2015      metad agricultural developmet plc      1950-2200
# 1             2014/2015      metad agricultural developmet plc      1950-2200
# 2                   NaN                                    NaN  1600 - 1800 m
# 3                   NaN  yidnekachew debessa coffee plantation      1800-2200
# 4             2014/2015      metad agricultural developmet plc      1950-2200
# ...                 ...                                    ...            ...
# 1334                NaN                              robustasa            NaN
# 1335                NaN                              robustasa             40
# 1336                NaN                global opportunity fund     795 meters
# 1337  14-1118-2014-0087                          cafe politico            NaN
# 1338                NaN                          cafe politico            NaN
#
#       ...       Color Category.Two.Defects           Expiration  \
# 0     ...       Green                    0      April 3rd, 2016
# 1     ...       Green                    1      April 3rd, 2016
# 2     ...         NaN                    0       May 31st, 2011
# 3     ...       Green                    2     March 25th, 2016
# 4     ...       Green                    2      April 3rd, 2016
# ...   ...         ...                  ...                  ...
# 1334  ...  Blue-Green                    1   January 18th, 2017
# 1335  ...  Blue-Green                    0   January 18th, 2017
# 1336  ...         NaN                    6  December 23rd, 2015
# 1337  ...       Green                    1    August 25th, 2015
# 1338  ...         NaN                    9    August 25th, 2015
#
#                       Certification.Body  \
# 0     METAD Agricultural Development plc
# 1     METAD Agricultural Development plc
# 2           Specialty Coffee Association
# 3     METAD Agricultural Development plc
# 4     METAD Agricultural Development plc
# ...                                  ...
# 1334        Specialty Coffee Association
# 1335        Specialty Coffee Association
# 1336        Specialty Coffee Association
# 1337        Specialty Coffee Association
# 1338        Specialty Coffee Association
#
#                          Certification.Address  \
# 0     309fcf77415a3661ae83e027f7e5f05dad786e44
# 1     309fcf77415a3661ae83e027f7e5f05dad786e44
# 2     36d0d00a3724338ba7937c52a378d085f2172daa
# 3     309fcf77415a3661ae83e027f7e5f05dad786e44
# 4     309fcf77415a3661ae83e027f7e5f05dad786e44
# ...                                        ...
# 1334  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1335  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1336  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1337  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1338  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
#
#                          Certification.Contact unit_of_measurement  \
# 0     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 1     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 2     0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 3     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 4     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# ...                                        ...                 ...
# 1334  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1335  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1336  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1337  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1338  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
#
#      altitude_low_meters altitude_high_meters altitude_mean_meters
# 0                 1950.0               2200.0               2075.0
# 1                 1950.0               2200.0               2075.0
# 2                 1600.0               1800.0               1700.0
# 3                 1800.0               2200.0               2000.0
# 4                 1950.0               2200.0               2075.0
# ...                  ...                  ...                  ...
# 1334                 NaN                  NaN                  NaN
# 1335                40.0                 40.0                 40.0
# 1336               795.0                795.0                795.0
# 1337                 NaN                  NaN                  NaN
# 1338                 NaN                  NaN                  NaN
#
# [1339 rows x 44 columns]

# %%
coffee.set_index(coffee.columns[0])
# Out:
#             Species                     Owner Country.of.Origin  \
# Unnamed: 0
# 0           Arabica                 metad plc          Ethiopia
# 1           Arabica                 metad plc          Ethiopia
# 2           Arabica  grounds for health admin         Guatemala
# 3           Arabica       yidnekachew dabessa          Ethiopia
# 4           Arabica                 metad plc          Ethiopia
# ...             ...                       ...               ...
# 1334        Robusta               luis robles           Ecuador
# 1335        Robusta               luis robles           Ecuador
# 1336        Robusta               james moore     United States
# 1337        Robusta             cafe politico             India
# 1338        Robusta             cafe politico           Vietnam
#
#                                            Farm.Name Lot.Number  \
# Unnamed: 0
# 0                                          metad plc        NaN
# 1                                          metad plc        NaN
# 2           san marcos barrancas "san cristobal cuch        NaN
# 3              yidnekachew dabessa coffee plantation        NaN
# 4                                          metad plc        NaN
# ...                                              ...        ...
# 1334                                       robustasa   Lavado 1
# 1335                                       robustasa   Lavado 3
# 1336                                 fazenda cazengo        NaN
# 1337                                             NaN        NaN
# 1338                                             NaN        NaN
#
#                       Mill         ICO.Number  \
# Unnamed: 0
# 0                metad plc          2014/2015
# 1                metad plc          2014/2015
# 2                      NaN                NaN
# 3                  wolensu                NaN
# 4                metad plc          2014/2015
# ...                    ...                ...
# 1334           our own lab                NaN
# 1335        own laboratory                NaN
# 1336          cafe cazengo                NaN
# 1337                   NaN  14-1118-2014-0087
# 1338                   NaN                NaN
#
#                                           Company       Altitude  \
# Unnamed: 0
# 0               metad agricultural developmet plc      1950-2200
# 1               metad agricultural developmet plc      1950-2200
# 2                                             NaN  1600 - 1800 m
# 3           yidnekachew debessa coffee plantation      1800-2200
# 4               metad agricultural developmet plc      1950-2200
# ...                                           ...            ...
# 1334                                    robustasa            NaN
# 1335                                    robustasa             40
# 1336                      global opportunity fund     795 meters
# 1337                                cafe politico            NaN
# 1338                                cafe politico            NaN
#
#                                    Region  ...       Color  \
# Unnamed: 0                                 ...
# 0                            guji-hambela  ...       Green
# 1                            guji-hambela  ...       Green
# 2                                     NaN  ...         NaN
# 3                                  oromia  ...       Green
# 4                            guji-hambela  ...       Green
# ...                                   ...  ...         ...
# 1334                     san juan, playas  ...  Blue-Green
# 1335                     san juan, playas  ...  Blue-Green
# 1336        kwanza norte province, angola  ...         NaN
# 1337                                  NaN  ...       Green
# 1338                                  NaN  ...         NaN
#
#             Category.Two.Defects           Expiration  \
# Unnamed: 0
# 0                              0      April 3rd, 2016
# 1                              1      April 3rd, 2016
# 2                              0       May 31st, 2011
# 3                              2     March 25th, 2016
# 4                              2      April 3rd, 2016
# ...                          ...                  ...
# 1334                           1   January 18th, 2017
# 1335                           0   January 18th, 2017
# 1336                           6  December 23rd, 2015
# 1337                           1    August 25th, 2015
# 1338                           9    August 25th, 2015
#
#                             Certification.Body  \
# Unnamed: 0
# 0           METAD Agricultural Development plc
# 1           METAD Agricultural Development plc
# 2                 Specialty Coffee Association
# 3           METAD Agricultural Development plc
# 4           METAD Agricultural Development plc
# ...                                        ...
# 1334              Specialty Coffee Association
# 1335              Specialty Coffee Association
# 1336              Specialty Coffee Association
# 1337              Specialty Coffee Association
# 1338              Specialty Coffee Association
#
#                                Certification.Address  \
# Unnamed: 0
# 0           309fcf77415a3661ae83e027f7e5f05dad786e44
# 1           309fcf77415a3661ae83e027f7e5f05dad786e44
# 2           36d0d00a3724338ba7937c52a378d085f2172daa
# 3           309fcf77415a3661ae83e027f7e5f05dad786e44
# 4           309fcf77415a3661ae83e027f7e5f05dad786e44
# ...                                              ...
# 1334        ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1335        ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1336        ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1337        ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1338        ff7c18ad303d4b603ac3f8cff7e611ffc735e720
#
#                                Certification.Contact unit_of_measurement  \
# Unnamed: 0
# 0           19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 1           19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 2           0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 3           19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 4           19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# ...                                              ...                 ...
# 1334        352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1335        352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1336        352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1337        352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1338        352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
#
#            altitude_low_meters altitude_high_meters  altitude_mean_meters
# Unnamed: 0
# 0                       1950.0               2200.0                2075.0
# 1                       1950.0               2200.0                2075.0
# 2                       1600.0               1800.0                1700.0
# 3                       1800.0               2200.0                2000.0
# 4                       1950.0               2200.0                2075.0
# ...                        ...                  ...                   ...
# 1334                       NaN                  NaN                   NaN
# 1335                      40.0                 40.0                  40.0
# 1336                     795.0                795.0                 795.0
# 1337                       NaN                  NaN                   NaN
# 1338                       NaN                  NaN                   NaN
#
# [1339 rows x 43 columns]

# %% [markdown]
# ### Problem 2. Observations and features (1 point)
# How many observations are there? How many features? Which features are numerical, and which are categorical?
#
# **Note:** Think about the _meaning_, not the data types. The dataset hasn't been thoroughly cleaned.

# %%
coffee_set.head(10).T
# Out:
#                                                               0  \
# Species                                                 Arabica
# Owner                                                 metad plc
# Country.of.Origin                                      Ethiopia
# Farm.Name                                             metad plc
# Lot.Number                                                  NaN
# Mill                                                  metad plc
# ICO.Number                                            2014/2015
# Company                       metad agricultural developmet plc
# Altitude                                              1950-2200
# Region                                             guji-hambela
# Producer                                              METAD PLC
# Number.of.Bags                                              300
# Bag.Weight                                                60 kg
# In.Country.Partner           METAD Agricultural Development plc
# Harvest.Year                                               2014
# Grading.Date                                    April 4th, 2015
# Owner.1                                               metad plc
# Variety                                                     NaN
# Processing.Method                                  Washed / Wet
# Aroma                                                      8.67
# Flavor                                                     8.83
# Aftertaste                                                 8.67
# Acidity                                                    8.75
# Body                                                        8.5
# Balance                                                    8.42
# Uniformity                                                 10.0
# Clean.Cup                                                  10.0
# Sweetness                                                  10.0
# Cupper.Points                                              8.75
# Total.Cup.Points                                          90.58
# Moisture                                                   0.12
# Category.One.Defects                                          0
# Quakers                                                     0.0
# Color                                                     Green
# Category.Two.Defects                                          0
# Expiration                                      April 3rd, 2016
# Certification.Body           METAD Agricultural Development plc
# Certification.Address  309fcf77415a3661ae83e027f7e5f05dad786e44
# Certification.Contact  19fef5a731de2db57d16da10287413f5f99bc2dd
# unit_of_measurement                                           m
# altitude_low_meters                                      1950.0
# altitude_high_meters                                     2200.0
# altitude_mean_meters                                     2075.0
#
#                                                               1  \
# Species                                                 Arabica
# Owner                                                 metad plc
# Country.of.Origin                                      Ethiopia
# Farm.Name                                             metad plc
# Lot.Number                                                  NaN
# Mill                                                  metad plc
# ICO.Number                                            2014/2015
# Company                       metad agricultural developmet plc
# Altitude                                              1950-2200
# Region                                             guji-hambela
# Producer                                              METAD PLC
# Number.of.Bags                                              300
# Bag.Weight                                                60 kg
# In.Country.Partner           METAD Agricultural Development plc
# Harvest.Year                                               2014
# Grading.Date                                    April 4th, 2015
# Owner.1                                               metad plc
# Variety                                                   Other
# Processing.Method                                  Washed / Wet
# Aroma                                                      8.75
# Flavor                                                     8.67
# Aftertaste                                                  8.5
# Acidity                                                    8.58
# Body                                                       8.42
# Balance                                                    8.42
# Uniformity                                                 10.0
# Clean.Cup                                                  10.0
# Sweetness                                                  10.0
# Cupper.Points                                              8.58
# Total.Cup.Points                                          89.92
# Moisture                                                   0.12
# Category.One.Defects                                          0
# Quakers                                                     0.0
# Color                                                     Green
# Category.Two.Defects                                          1
# Expiration                                      April 3rd, 2016
# Certification.Body           METAD Agricultural Development plc
# Certification.Address  309fcf77415a3661ae83e027f7e5f05dad786e44
# Certification.Contact  19fef5a731de2db57d16da10287413f5f99bc2dd
# unit_of_measurement                                           m
# altitude_low_meters                                      1950.0
# altitude_high_meters                                     2200.0
# altitude_mean_meters                                     2075.0
#
#                                                               2  \
# Species                                                 Arabica
# Owner                                  grounds for health admin
# Country.of.Origin                                     Guatemala
# Farm.Name              san marcos barrancas "san cristobal cuch
# Lot.Number                                                  NaN
# Mill                                                        NaN
# ICO.Number                                                  NaN
# Company                                                     NaN
# Altitude                                          1600 - 1800 m
# Region                                                      NaN
# Producer                                                    NaN
# Number.of.Bags                                                5
# Bag.Weight                                                    1
# In.Country.Partner                 Specialty Coffee Association
# Harvest.Year                                                NaN
# Grading.Date                                     May 31st, 2010
# Owner.1                                Grounds for Health Admin
# Variety                                                 Bourbon
# Processing.Method                                           NaN
# Aroma                                                      8.42
# Flavor                                                      8.5
# Aftertaste                                                 8.42
# Acidity                                                    8.42
# Body                                                       8.33
# Balance                                                    8.42
# Uniformity                                                 10.0
# Clean.Cup                                                  10.0
# Sweetness                                                  10.0
# Cupper.Points                                              9.25
# Total.Cup.Points                                          89.75
# Moisture                                                    0.0
# Category.One.Defects                                          0
# Quakers                                                     0.0
# Color                                                       NaN
# Category.Two.Defects                                          0
# Expiration                                       May 31st, 2011
# Certification.Body                 Specialty Coffee Association
# Certification.Address  36d0d00a3724338ba7937c52a378d085f2172daa
# Certification.Contact  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660
# unit_of_measurement                                           m
# altitude_low_meters                                      1600.0
# altitude_high_meters                                     1800.0
# altitude_mean_meters                                     1700.0
#
#                                                               3  \
# Species                                                 Arabica
# Owner                                       yidnekachew dabessa
# Country.of.Origin                                      Ethiopia
# Farm.Name                 yidnekachew dabessa coffee plantation
# Lot.Number                                                  NaN
# Mill                                                    wolensu
# ICO.Number                                                  NaN
# Company                   yidnekachew debessa coffee plantation
# Altitude                                              1800-2200
# Region                                                   oromia
# Producer                  Yidnekachew Dabessa Coffee Plantation
# Number.of.Bags                                              320
# Bag.Weight                                                60 kg
# In.Country.Partner           METAD Agricultural Development plc
# Harvest.Year                                               2014
# Grading.Date                                   March 26th, 2015
# Owner.1                                     Yidnekachew Dabessa
# Variety                                                     NaN
# Processing.Method                                 Natural / Dry
# Aroma                                                      8.17
# Flavor                                                     8.58
# Aftertaste                                                 8.42
# Acidity                                                    8.42
# Body                                                        8.5
# Balance                                                    8.25
# Uniformity                                                 10.0
# Clean.Cup                                                  10.0
# Sweetness                                                  10.0
# Cupper.Points                                              8.67
# Total.Cup.Points                                           89.0
# Moisture                                                   0.11
# Category.One.Defects                                          0
# Quakers                                                     0.0
# Color                                                     Green
# Category.Two.Defects                                          2
# Expiration                                     March 25th, 2016
# Certification.Body           METAD Agricultural Development plc
# Certification.Address  309fcf77415a3661ae83e027f7e5f05dad786e44
# Certification.Contact  19fef5a731de2db57d16da10287413f5f99bc2dd
# unit_of_measurement                                           m
# altitude_low_meters                                      1800.0
# altitude_high_meters                                     2200.0
# altitude_mean_meters                                     2000.0
#
#                                                               4  \
# Species                                                 Arabica
# Owner                                                 metad plc
# Country.of.Origin                                      Ethiopia
# Farm.Name                                             metad plc
# Lot.Number                                                  NaN
# Mill                                                  metad plc
# ICO.Number                                            2014/2015
# Company                       metad agricultural developmet plc
# Altitude                                              1950-2200
# Region                                             guji-hambela
# Producer                                              METAD PLC
# Number.of.Bags                                              300
# Bag.Weight                                                60 kg
# In.Country.Partner           METAD Agricultural Development plc
# Harvest.Year                                               2014
# Grading.Date                                    April 4th, 2015
# Owner.1                                               metad plc
# Variety                                                   Other
# Processing.Method                                  Washed / Wet
# Aroma                                                      8.25
# Flavor                                                      8.5
# Aftertaste                                                 8.25
# Acidity                                                     8.5
# Body                                                       8.42
# Balance                                                    8.33
# Uniformity                                                 10.0
# Clean.Cup                                                  10.0
# Sweetness                                                  10.0
# Cupper.Points                                              8.58
# Total.Cup.Points                                          88.83
# Moisture                                                   0.12
# Category.One.Defects                                          0
# Quakers                                                     0.0
# Color                                                     Green
# Category.Two.Defects                                          2
# Expiration                                      April 3rd, 2016
# Certification.Body           METAD Agricultural Development plc
# Certification.Address  309fcf77415a3661ae83e027f7e5f05dad786e44
# Certification.Contact  19fef5a731de2db57d16da10287413f5f99bc2dd
# unit_of_measurement                                           m
# altitude_low_meters                                      1950.0
# altitude_high_meters                                     2200.0
# altitude_mean_meters                                     2075.0
#
#                                                               5  \
# Species                                                 Arabica
# Owner                                                 ji-ae ahn
# Country.of.Origin                                        Brazil
# Farm.Name                                                   NaN
# Lot.Number                                                  NaN
# Mill                                                        NaN
# ICO.Number                                                  NaN
# Company                                                     NaN
# Altitude                                                    NaN
# Region                                                      NaN
# Producer                                                    NaN
# Number.of.Bags                                              100
# Bag.Weight                                                30 kg
# In.Country.Partner           Specialty Coffee Institute of Asia
# Harvest.Year                                               2013
# Grading.Date                                September 3rd, 2013
# Owner.1                                               Ji-Ae Ahn
# Variety                                                     NaN
# Processing.Method                                 Natural / Dry
# Aroma                                                      8.58
# Flavor                                                     8.42
# Aftertaste                                                 8.42
# Acidity                                                     8.5
# Body                                                       8.25
# Balance                                                    8.33
# Uniformity                                                 10.0
# Clean.Cup                                                  10.0
# Sweetness                                                  10.0
# Cupper.Points                                              8.33
# Total.Cup.Points                                          88.83
# Moisture                                                   0.11
# Category.One.Defects                                          0
# Quakers                                                     0.0
# Color                                              Bluish-Green
# Category.Two.Defects                                          1
# Expiration                                  September 3rd, 2014
# Certification.Body           Specialty Coffee Institute of Asia
# Certification.Address  726e4891cf2c9a4848768bd34b668124d12c4224
# Certification.Contact  b70da261fcc84831e3e9620c30a8701540abc200
# unit_of_measurement                                           m
# altitude_low_meters                                         NaN
# altitude_high_meters                                        NaN
# altitude_mean_meters                                        NaN
#
#                                                               6  \
# Species                                                 Arabica
# Owner                                             hugo valdivia
# Country.of.Origin                                          Peru
# Farm.Name                                                   NaN
# Lot.Number                                                  NaN
# Mill                                                        hvc
# ICO.Number                                                  NaN
# Company                   richmond investment-coffee department
# Altitude                                                    NaN
# Region                                                      NaN
# Producer                                                    HVC
# Number.of.Bags                                              100
# Bag.Weight                                                69 kg
# In.Country.Partner           Specialty Coffee Institute of Asia
# Harvest.Year                                               2012
# Grading.Date                               September 17th, 2012
# Owner.1                                           Hugo Valdivia
# Variety                                                   Other
# Processing.Method                                  Washed / Wet
# Aroma                                                      8.42
# Flavor                                                      8.5
# Aftertaste                                                 8.33
# Acidity                                                     8.5
# Body                                                       8.25
# Balance                                                    8.25
# Uniformity                                                 10.0
# Clean.Cup                                                  10.0
# Sweetness                                                  10.0
# Cupper.Points                                               8.5
# Total.Cup.Points                                          88.75
# Moisture                                                   0.11
# Category.One.Defects                                          0
# Quakers                                                     0.0
# Color                                              Bluish-Green
# Category.Two.Defects                                          0
# Expiration                                 September 17th, 2013
# Certification.Body           Specialty Coffee Institute of Asia
# Certification.Address  726e4891cf2c9a4848768bd34b668124d12c4224
# Certification.Contact  b70da261fcc84831e3e9620c30a8701540abc200
# unit_of_measurement                                           m
# altitude_low_meters                                         NaN
# altitude_high_meters                                        NaN
# altitude_mean_meters                                        NaN
#
#                                                                7  \
# Species                                                  Arabica
# Owner                                ethiopia commodity exchange
# Country.of.Origin                                       Ethiopia
# Farm.Name                                                  aolme
# Lot.Number                                                   NaN
# Mill                                                     c.p.w.e
# ICO.Number                                              010/0338
# Company                                                      NaN
# Altitude                                               1570-1700
# Region                                                    oromia
# Producer               Bazen Agricultural & Industrial Dev't Plc
# Number.of.Bags                                               300
# Bag.Weight                                                 60 kg
# In.Country.Partner                   Ethiopia Commodity Exchange
# Harvest.Year                                          March 2010
# Grading.Date                                 September 2nd, 2010
# Owner.1                              Ethiopia Commodity Exchange
# Variety                                                      NaN
# Processing.Method                                            NaN
# Aroma                                                       8.25
# Flavor                                                      8.33
# Aftertaste                                                   8.5
# Acidity                                                     8.42
# Body                                                        8.33
# Balance                                                      8.5
# Uniformity                                                  10.0
# Clean.Cup                                                   10.0
# Sweetness                                                   9.33
# Cupper.Points                                                9.0
# Total.Cup.Points                                           88.67
# Moisture                                                    0.03
# Category.One.Defects                                           0
# Quakers                                                      0.0
# Color                                                        NaN
# Category.Two.Defects                                           0
# Expiration                                   September 2nd, 2011
# Certification.Body                   Ethiopia Commodity Exchange
# Certification.Address   a176532400aebdc345cf3d870f84ed3ecab6249e
# Certification.Contact   61bbaf6a9f341e5782b8e7bd3ebf76aac89fe24b
# unit_of_measurement                                            m
# altitude_low_meters                                       1570.0
# altitude_high_meters                                      1700.0
# altitude_mean_meters                                      1635.0
#
#                                                                8  \
# Species                                                  Arabica
# Owner                                ethiopia commodity exchange
# Country.of.Origin                                       Ethiopia
# Farm.Name                                                  aolme
# Lot.Number                                                   NaN
# Mill                                                     c.p.w.e
# ICO.Number                                              010/0338
# Company                                                      NaN
# Altitude                                               1570-1700
# Region                                                   oromiya
# Producer               Bazen Agricultural & Industrial Dev't Plc
# Number.of.Bags                                               300
# Bag.Weight                                                 60 kg
# In.Country.Partner                   Ethiopia Commodity Exchange
# Harvest.Year                                          March 2010
# Grading.Date                                 September 2nd, 2010
# Owner.1                              Ethiopia Commodity Exchange
# Variety                                                      NaN
# Processing.Method                                            NaN
# Aroma                                                       8.67
# Flavor                                                      8.67
# Aftertaste                                                  8.58
# Acidity                                                     8.42
# Body                                                        8.33
# Balance                                                     8.42
# Uniformity                                                  9.33
# Clean.Cup                                                   10.0
# Sweetness                                                   9.33
# Cupper.Points                                               8.67
# Total.Cup.Points                                           88.42
# Moisture                                                    0.03
# Category.One.Defects                                           0
# Quakers                                                      0.0
# Color                                                        NaN
# Category.Two.Defects                                           0
# Expiration                                   September 2nd, 2011
# Certification.Body                   Ethiopia Commodity Exchange
# Certification.Address   a176532400aebdc345cf3d870f84ed3ecab6249e
# Certification.Contact   61bbaf6a9f341e5782b8e7bd3ebf76aac89fe24b
# unit_of_measurement                                            m
# altitude_low_meters                                       1570.0
# altitude_high_meters                                      1700.0
# altitude_mean_meters                                      1635.0
#
#                                                               9
# Species                                                 Arabica
# Owner                                    diamond enterprise plc
# Country.of.Origin                                      Ethiopia
# Farm.Name                                     tulla coffee farm
# Lot.Number                                                  NaN
# Mill                                          tulla coffee farm
# ICO.Number                                              2014/15
# Company                                  diamond enterprise plc
# Altitude                                              1795-1850
# Region                              snnp/kaffa zone,gimbowereda
# Producer                                 Diamond Enterprise Plc
# Number.of.Bags                                               50
# Bag.Weight                                                60 kg
# In.Country.Partner           METAD Agricultural Development plc
# Harvest.Year                                               2014
# Grading.Date                                   March 30th, 2015
# Owner.1                                  Diamond Enterprise Plc
# Variety                                                   Other
# Processing.Method                                 Natural / Dry
# Aroma                                                      8.08
# Flavor                                                     8.58
# Aftertaste                                                  8.5
# Acidity                                                     8.5
# Body                                                       7.67
# Balance                                                    8.42
# Uniformity                                                 10.0
# Clean.Cup                                                  10.0
# Sweetness                                                  10.0
# Cupper.Points                                               8.5
# Total.Cup.Points                                          88.25
# Moisture                                                    0.1
# Category.One.Defects                                          0
# Quakers                                                     0.0
# Color                                                     Green
# Category.Two.Defects                                          4
# Expiration                                     March 29th, 2016
# Certification.Body           METAD Agricultural Development plc
# Certification.Address  309fcf77415a3661ae83e027f7e5f05dad786e44
# Certification.Contact  19fef5a731de2db57d16da10287413f5f99bc2dd
# unit_of_measurement                                           m
# altitude_low_meters                                      1795.0
# altitude_high_meters                                     1850.0
# altitude_mean_meters                                     1822.5

# %%
coffee_set.shape
# Out:
# (1339, 43)

# %%
coffee_set.columns
# Out:
# Index(['Species', 'Owner', 'Country.of.Origin', 'Farm.Name', 'Lot.Number',
#        'Mill', 'ICO.Number', 'Company', 'Altitude', 'Region', 'Producer',
#        'Number.of.Bags', 'Bag.Weight', 'In.Country.Partner', 'Harvest.Year',
#        'Grading.Date', 'Owner.1', 'Variety', 'Processing.Method', 'Aroma',
#        'Flavor', 'Aftertaste', 'Acidity', 'Body', 'Balance', 'Uniformity',
#        'Clean.Cup', 'Sweetness', 'Cupper.Points', 'Total.Cup.Points',
#        'Moisture', 'Category.One.Defects', 'Quakers', 'Color',
#        'Category.Two.Defects', 'Expiration', 'Certification.Body',
#        'Certification.Address', 'Certification.Contact', 'unit_of_measurement',
#        'altitude_low_meters', 'altitude_high_meters', 'altitude_mean_meters'],
#       dtype='object')

# %%
coffee_set.dtypes
# Out:
# Species                   object
# Owner                     object
# Country.of.Origin         object
# Farm.Name                 object
# Lot.Number                object
# Mill                      object
# ICO.Number                object
# Company                   object
# Altitude                  object
# Region                    object
# Producer                  object
# Number.of.Bags             int64
# Bag.Weight                object
# In.Country.Partner        object
# Harvest.Year              object
# Grading.Date              object
# Owner.1                   object
# Variety                   object
# Processing.Method         object
# Aroma                    float64
# Flavor                   float64
# Aftertaste               float64
# Acidity                  float64
# Body                     float64
# Balance                  float64
# Uniformity               float64
# Clean.Cup                float64
# Sweetness                float64
# Cupper.Points            float64
# Total.Cup.Points         float64
# Moisture                 float64
# Category.One.Defects       int64
# Quakers                  float64
# Color                     object
# Category.Two.Defects       int64
# Expiration                object
# Certification.Body        object
# Certification.Address     object
# Certification.Contact     object
# unit_of_measurement       object
# altitude_low_meters      float64
# altitude_high_meters     float64
# altitude_mean_meters     float64
# dtype: object

# %%
coffee_set.Uniformity.value_counts(dropna = False)
# Out:
# Uniformity
# 10.00    1152
# 9.33      116
# 8.67       31
# 8.00       25
# 6.67        7
# 6.00        3
# 7.33        2
# 9.50        1
# 9.00        1
# 0.00        1
# Name: count, dtype: int64

# %%
coffee_set[["In.Country.Partner", "Certification.Body"]].value_counts(dropna = False)
coffee_set["In.Country.Partner"].value_counts(), coffee_set["Certification.Body"].value_counts()
coffee_set['In.Country.Partner'].compare(coffee_set['Certification.Body'])
# Out:
#                      self                                       other
# 219  Specialty Coffee Ass  Specialty Coffee Association of Costa Rica

# %%
coffee_set.unit_of_measurement.value_counts()
# Out:
# unit_of_measurement
# m     1157
# ft     182
# Name: count, dtype: int64

# %% [markdown]
# Dataset has 1339 observations and 43 features.

# %% [markdown]
# Numeric columns are:
# 'Altitude', 'Number.of.Bags', 'Bag.Weight', 'Harvest.Year','Grading.Date', 'Aroma',
# 'Flavor', 'Aftertaste', 'Acidity', 'Body', 'Balance', 'Uniformity','Clean.Cup', 'Sweetness', 'Cupper.Points', 'Total.Cup.Points',
# 'Moisture', 'Quakers', 'altitude_low_meters', 'altitude_high_meters', 'altitude_mean_meters'

# %% [markdown]
# Columns which are categorical:
# 'Species', 'Owner', 'Country.of.Origin', 'Processing.Method','Farm.Name', 'Lot.Number','Mill', 'ICO.Number', 'Company', 'Altitude', 'Region', 'Producer',
# 'In.Country.Partner', 'Grading.Date', 'Owner.1', 'Variety', 'Processing.Method','Category.One.Defects', 'Color', 'Category.Two.Defects',  'Certification.Body', 'Certification.Address', 'Certification.Contact',

# %% [markdown]
# Lot.Number is string, but is useless.
# Expiration & Grading.Date have to be datetime
# Column In.Country.Partner is almost the same as Certification.Body, we could erase Certification.Body
# Unit_of_measurement could be done all in meters
# Bag.Weight & Harvest.Year have to be number.

# %% [markdown]
# ### Problem 3. Column manipulation (1 point)
# Make the column names more Pythonic (which helps with the quality and... aesthetics). Convert column names to `snake_case`, i.e. `species`, `country_of_origin`, `ico_number`, etc. Try to not do it manually.

# %%
coffee_set.columns = coffee_set.columns.str.lower().str.replace(".","_")
coffee_set.T
# Out:
#                                                            0     \
# species                                                 Arabica
# owner                                                 metad plc
# country_of_origin                                      Ethiopia
# farm_name                                             metad plc
# lot_number                                                  NaN
# mill                                                  metad plc
# ico_number                                            2014/2015
# company                       metad agricultural developmet plc
# altitude                                              1950-2200
# region                                             guji-hambela
# producer                                              METAD PLC
# number_of_bags                                              300
# bag_weight                                                60 kg
# in_country_partner           METAD Agricultural Development plc
# harvest_year                                               2014
# grading_date                                    April 4th, 2015
# owner_1                                               metad plc
# variety                                                     NaN
# processing_method                                  Washed / Wet
# aroma                                                      8.67
# flavor                                                     8.83
# aftertaste                                                 8.67
# acidity                                                    8.75
# body                                                        8.5
# balance                                                    8.42
# uniformity                                                 10.0
# clean_cup                                                  10.0
# sweetness                                                  10.0
# cupper_points                                              8.75
# total_cup_points                                          90.58
# moisture                                                   0.12
# category_one_defects                                          0
# quakers                                                     0.0
# color                                                     Green
# category_two_defects                                          0
# expiration                                      April 3rd, 2016
# certification_body           METAD Agricultural Development plc
# certification_address  309fcf77415a3661ae83e027f7e5f05dad786e44
# certification_contact  19fef5a731de2db57d16da10287413f5f99bc2dd
# unit_of_measurement                                           m
# altitude_low_meters                                      1950.0
# altitude_high_meters                                     2200.0
# altitude_mean_meters                                     2075.0
#
#                                                            1     \
# species                                                 Arabica
# owner                                                 metad plc
# country_of_origin                                      Ethiopia
# farm_name                                             metad plc
# lot_number                                                  NaN
# mill                                                  metad plc
# ico_number                                            2014/2015
# company                       metad agricultural developmet plc
# altitude                                              1950-2200
# region                                             guji-hambela
# producer                                              METAD PLC
# number_of_bags                                              300
# bag_weight                                                60 kg
# in_country_partner           METAD Agricultural Development plc
# harvest_year                                               2014
# grading_date                                    April 4th, 2015
# owner_1                                               metad plc
# variety                                                   Other
# processing_method                                  Washed / Wet
# aroma                                                      8.75
# flavor                                                     8.67
# aftertaste                                                  8.5
# acidity                                                    8.58
# body                                                       8.42
# balance                                                    8.42
# uniformity                                                 10.0
# clean_cup                                                  10.0
# sweetness                                                  10.0
# cupper_points                                              8.58
# total_cup_points                                          89.92
# moisture                                                   0.12
# category_one_defects                                          0
# quakers                                                     0.0
# color                                                     Green
# category_two_defects                                          1
# expiration                                      April 3rd, 2016
# certification_body           METAD Agricultural Development plc
# certification_address  309fcf77415a3661ae83e027f7e5f05dad786e44
# certification_contact  19fef5a731de2db57d16da10287413f5f99bc2dd
# unit_of_measurement                                           m
# altitude_low_meters                                      1950.0
# altitude_high_meters                                     2200.0
# altitude_mean_meters                                     2075.0
#
#                                                            2     \
# species                                                 Arabica
# owner                                  grounds for health admin
# country_of_origin                                     Guatemala
# farm_name              san marcos barrancas "san cristobal cuch
# lot_number                                                  NaN
# mill                                                        NaN
# ico_number                                                  NaN
# company                                                     NaN
# altitude                                          1600 - 1800 m
# region                                                      NaN
# producer                                                    NaN
# number_of_bags                                                5
# bag_weight                                                    1
# in_country_partner                 Specialty Coffee Association
# harvest_year                                                NaN
# grading_date                                     May 31st, 2010
# owner_1                                Grounds for Health Admin
# variety                                                 Bourbon
# processing_method                                           NaN
# aroma                                                      8.42
# flavor                                                      8.5
# aftertaste                                                 8.42
# acidity                                                    8.42
# body                                                       8.33
# balance                                                    8.42
# uniformity                                                 10.0
# clean_cup                                                  10.0
# sweetness                                                  10.0
# cupper_points                                              9.25
# total_cup_points                                          89.75
# moisture                                                    0.0
# category_one_defects                                          0
# quakers                                                     0.0
# color                                                       NaN
# category_two_defects                                          0
# expiration                                       May 31st, 2011
# certification_body                 Specialty Coffee Association
# certification_address  36d0d00a3724338ba7937c52a378d085f2172daa
# certification_contact  0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660
# unit_of_measurement                                           m
# altitude_low_meters                                      1600.0
# altitude_high_meters                                     1800.0
# altitude_mean_meters                                     1700.0
#
#                                                            3     \
# species                                                 Arabica
# owner                                       yidnekachew dabessa
# country_of_origin                                      Ethiopia
# farm_name                 yidnekachew dabessa coffee plantation
# lot_number                                                  NaN
# mill                                                    wolensu
# ico_number                                                  NaN
# company                   yidnekachew debessa coffee plantation
# altitude                                              1800-2200
# region                                                   oromia
# producer                  Yidnekachew Dabessa Coffee Plantation
# number_of_bags                                              320
# bag_weight                                                60 kg
# in_country_partner           METAD Agricultural Development plc
# harvest_year                                               2014
# grading_date                                   March 26th, 2015
# owner_1                                     Yidnekachew Dabessa
# variety                                                     NaN
# processing_method                                 Natural / Dry
# aroma                                                      8.17
# flavor                                                     8.58
# aftertaste                                                 8.42
# acidity                                                    8.42
# body                                                        8.5
# balance                                                    8.25
# uniformity                                                 10.0
# clean_cup                                                  10.0
# sweetness                                                  10.0
# cupper_points                                              8.67
# total_cup_points                                           89.0
# moisture                                                   0.11
# category_one_defects                                          0
# quakers                                                     0.0
# color                                                     Green
# category_two_defects                                          2
# expiration                                     March 25th, 2016
# certification_body           METAD Agricultural Development plc
# certification_address  309fcf77415a3661ae83e027f7e5f05dad786e44
# certification_contact  19fef5a731de2db57d16da10287413f5f99bc2dd
# unit_of_measurement                                           m
# altitude_low_meters                                      1800.0
# altitude_high_meters                                     2200.0
# altitude_mean_meters                                     2000.0
#
#                                                            4     \
# species                                                 Arabica
# owner                                                 metad plc
# country_of_origin                                      Ethiopia
# farm_name                                             metad plc
# lot_number                                                  NaN
# mill                                                  metad plc
# ico_number                                            2014/2015
# company                       metad agricultural developmet plc
# altitude                                              1950-2200
# region                                             guji-hambela
# producer                                              METAD PLC
# number_of_bags                                              300
# bag_weight                                                60 kg
# in_country_partner           METAD Agricultural Development plc
# harvest_year                                               2014
# grading_date                                    April 4th, 2015
# owner_1                                               metad plc
# variety                                                   Other
# processing_method                                  Washed / Wet
# aroma                                                      8.25
# flavor                                                      8.5
# aftertaste                                                 8.25
# acidity                                                     8.5
# body                                                       8.42
# balance                                                    8.33
# uniformity                                                 10.0
# clean_cup                                                  10.0
# sweetness                                                  10.0
# cupper_points                                              8.58
# total_cup_points                                          88.83
# moisture                                                   0.12
# category_one_defects                                          0
# quakers                                                     0.0
# color                                                     Green
# category_two_defects                                          2
# expiration                                      April 3rd, 2016
# certification_body           METAD Agricultural Development plc
# certification_address  309fcf77415a3661ae83e027f7e5f05dad786e44
# certification_contact  19fef5a731de2db57d16da10287413f5f99bc2dd
# unit_of_measurement                                           m
# altitude_low_meters                                      1950.0
# altitude_high_meters                                     2200.0
# altitude_mean_meters                                     2075.0
#
#                                                            5     \
# species                                                 Arabica
# owner                                                 ji-ae ahn
# country_of_origin                                        Brazil
# farm_name                                                   NaN
# lot_number                                                  NaN
# mill                                                        NaN
# ico_number                                                  NaN
# company                                                     NaN
# altitude                                                    NaN
# region                                                      NaN
# producer                                                    NaN
# number_of_bags                                              100
# bag_weight                                                30 kg
# in_country_partner           Specialty Coffee Institute of Asia
# harvest_year                                               2013
# grading_date                                September 3rd, 2013
# owner_1                                               Ji-Ae Ahn
# variety                                                     NaN
# processing_method                                 Natural / Dry
# aroma                                                      8.58
# flavor                                                     8.42
# aftertaste                                                 8.42
# acidity                                                     8.5
# body                                                       8.25
# balance                                                    8.33
# uniformity                                                 10.0
# clean_cup                                                  10.0
# sweetness                                                  10.0
# cupper_points                                              8.33
# total_cup_points                                          88.83
# moisture                                                   0.11
# category_one_defects                                          0
# quakers                                                     0.0
# color                                              Bluish-Green
# category_two_defects                                          1
# expiration                                  September 3rd, 2014
# certification_body           Specialty Coffee Institute of Asia
# certification_address  726e4891cf2c9a4848768bd34b668124d12c4224
# certification_contact  b70da261fcc84831e3e9620c30a8701540abc200
# unit_of_measurement                                           m
# altitude_low_meters                                         NaN
# altitude_high_meters                                        NaN
# altitude_mean_meters                                        NaN
#
#                                                            6     \
# species                                                 Arabica
# owner                                             hugo valdivia
# country_of_origin                                          Peru
# farm_name                                                   NaN
# lot_number                                                  NaN
# mill                                                        hvc
# ico_number                                                  NaN
# company                   richmond investment-coffee department
# altitude                                                    NaN
# region                                                      NaN
# producer                                                    HVC
# number_of_bags                                              100
# bag_weight                                                69 kg
# in_country_partner           Specialty Coffee Institute of Asia
# harvest_year                                               2012
# grading_date                               September 17th, 2012
# owner_1                                           Hugo Valdivia
# variety                                                   Other
# processing_method                                  Washed / Wet
# aroma                                                      8.42
# flavor                                                      8.5
# aftertaste                                                 8.33
# acidity                                                     8.5
# body                                                       8.25
# balance                                                    8.25
# uniformity                                                 10.0
# clean_cup                                                  10.0
# sweetness                                                  10.0
# cupper_points                                               8.5
# total_cup_points                                          88.75
# moisture                                                   0.11
# category_one_defects                                          0
# quakers                                                     0.0
# color                                              Bluish-Green
# category_two_defects                                          0
# expiration                                 September 17th, 2013
# certification_body           Specialty Coffee Institute of Asia
# certification_address  726e4891cf2c9a4848768bd34b668124d12c4224
# certification_contact  b70da261fcc84831e3e9620c30a8701540abc200
# unit_of_measurement                                           m
# altitude_low_meters                                         NaN
# altitude_high_meters                                        NaN
# altitude_mean_meters                                        NaN
#
#                                                             7     \
# species                                                  Arabica
# owner                                ethiopia commodity exchange
# country_of_origin                                       Ethiopia
# farm_name                                                  aolme
# lot_number                                                   NaN
# mill                                                     c.p.w.e
# ico_number                                              010/0338
# company                                                      NaN
# altitude                                               1570-1700
# region                                                    oromia
# producer               Bazen Agricultural & Industrial Dev't Plc
# number_of_bags                                               300
# bag_weight                                                 60 kg
# in_country_partner                   Ethiopia Commodity Exchange
# harvest_year                                          March 2010
# grading_date                                 September 2nd, 2010
# owner_1                              Ethiopia Commodity Exchange
# variety                                                      NaN
# processing_method                                            NaN
# aroma                                                       8.25
# flavor                                                      8.33
# aftertaste                                                   8.5
# acidity                                                     8.42
# body                                                        8.33
# balance                                                      8.5
# uniformity                                                  10.0
# clean_cup                                                   10.0
# sweetness                                                   9.33
# cupper_points                                                9.0
# total_cup_points                                           88.67
# moisture                                                    0.03
# category_one_defects                                           0
# quakers                                                      0.0
# color                                                        NaN
# category_two_defects                                           0
# expiration                                   September 2nd, 2011
# certification_body                   Ethiopia Commodity Exchange
# certification_address   a176532400aebdc345cf3d870f84ed3ecab6249e
# certification_contact   61bbaf6a9f341e5782b8e7bd3ebf76aac89fe24b
# unit_of_measurement                                            m
# altitude_low_meters                                       1570.0
# altitude_high_meters                                      1700.0
# altitude_mean_meters                                      1635.0
#
#                                                             8     \
# species                                                  Arabica
# owner                                ethiopia commodity exchange
# country_of_origin                                       Ethiopia
# farm_name                                                  aolme
# lot_number                                                   NaN
# mill                                                     c.p.w.e
# ico_number                                              010/0338
# company                                                      NaN
# altitude                                               1570-1700
# region                                                   oromiya
# producer               Bazen Agricultural & Industrial Dev't Plc
# number_of_bags                                               300
# bag_weight                                                 60 kg
# in_country_partner                   Ethiopia Commodity Exchange
# harvest_year                                          March 2010
# grading_date                                 September 2nd, 2010
# owner_1                              Ethiopia Commodity Exchange
# variety                                                      NaN
# processing_method                                            NaN
# aroma                                                       8.67
# flavor                                                      8.67
# aftertaste                                                  8.58
# acidity                                                     8.42
# body                                                        8.33
# balance                                                     8.42
# uniformity                                                  9.33
# clean_cup                                                   10.0
# sweetness                                                   9.33
# cupper_points                                               8.67
# total_cup_points                                           88.42
# moisture                                                    0.03
# category_one_defects                                           0
# quakers                                                      0.0
# color                                                        NaN
# category_two_defects                                           0
# expiration                                   September 2nd, 2011
# certification_body                   Ethiopia Commodity Exchange
# certification_address   a176532400aebdc345cf3d870f84ed3ecab6249e
# certification_contact   61bbaf6a9f341e5782b8e7bd3ebf76aac89fe24b
# unit_of_measurement                                            m
# altitude_low_meters                                       1570.0
# altitude_high_meters                                      1700.0
# altitude_mean_meters                                      1635.0
#
#                                                            9     ...  \
# species                                                 Arabica  ...
# owner                                    diamond enterprise plc  ...
# country_of_origin                                      Ethiopia  ...
# farm_name                                     tulla coffee farm  ...
# lot_number                                                  NaN  ...
# mill                                          tulla coffee farm  ...
# ico_number                                              2014/15  ...
# company                                  diamond enterprise plc  ...
# altitude                                              1795-1850  ...
# region                              snnp/kaffa zone,gimbowereda  ...
# producer                                 Diamond Enterprise Plc  ...
# number_of_bags                                               50  ...
# bag_weight                                                60 kg  ...
# in_country_partner           METAD Agricultural Development plc  ...
# harvest_year                                               2014  ...
# grading_date                                   March 30th, 2015  ...
# owner_1                                  Diamond Enterprise Plc  ...
# variety                                                   Other  ...
# processing_method                                 Natural / Dry  ...
# aroma                                                      8.08  ...
# flavor                                                     8.58  ...
# aftertaste                                                  8.5  ...
# acidity                                                     8.5  ...
# body                                                       7.67  ...
# balance                                                    8.42  ...
# uniformity                                                 10.0  ...
# clean_cup                                                  10.0  ...
# sweetness                                                  10.0  ...
# cupper_points                                               8.5  ...
# total_cup_points                                          88.25  ...
# moisture                                                    0.1  ...
# category_one_defects                                          0  ...
# quakers                                                     0.0  ...
# color                                                     Green  ...
# category_two_defects                                          4  ...
# expiration                                     March 29th, 2016  ...
# certification_body           METAD Agricultural Development plc  ...
# certification_address  309fcf77415a3661ae83e027f7e5f05dad786e44  ...
# certification_contact  19fef5a731de2db57d16da10287413f5f99bc2dd  ...
# unit_of_measurement                                           m  ...
# altitude_low_meters                                      1795.0  ...
# altitude_high_meters                                     1850.0  ...
# altitude_mean_meters                                     1822.5  ...
#
#                                                            1329  \
# species                                                 Robusta
# owner                                             nitubaasa ltd
# country_of_origin                                        Uganda
# farm_name                     kigezi coffee farmers association
# lot_number                                                  NaN
# mill                                                  nitubaasa
# ico_number                                                    0
# company                                           nitubaasa ltd
# altitude                                                   1745
# region                                                  western
# producer                      Kigezi Coffee Farmers Association
# number_of_bags                                               20
# bag_weight                                                60 kg
# in_country_partner          Uganda Coffee Development Authority
# harvest_year                                               2013
# grading_date                                    June 27th, 2014
# owner_1                                           Nitubaasa Ltd
# variety                                                     NaN
# processing_method                                           NaN
# aroma                                                      7.83
# flavor                                                     7.58
# aftertaste                                                 7.33
# acidity                                                    7.67
# body                                                        7.5
# balance                                                     7.5
# uniformity                                                 10.0
# clean_cup                                                  10.0
# sweetness                                                  7.75
# cupper_points                                              7.42
# total_cup_points                                          80.58
# moisture                                                   0.12
# category_one_defects                                          0
# quakers                                                     0.0
# color                                                     Green
# category_two_defects                                          2
# expiration                                      June 27th, 2015
# certification_body          Uganda Coffee Development Authority
# certification_address  e36d0270932c3b657e96b7b0278dfd85dc0fe743
# certification_contact  03077a1c6bac60e6f514691634a7f6eb5c85aae8
# unit_of_measurement                                           m
# altitude_low_meters                                      1745.0
# altitude_high_meters                                     1745.0
# altitude_mean_meters                                     1745.0
#
#                                                            1330  \
# species                                                 Robusta
# owner                                     mannya coffee project
# country_of_origin                                        Uganda
# farm_name                                 mannya coffee project
# lot_number                                                  NaN
# mill                                      mannya coffee project
# ico_number                                                    0
# company                                   mannya coffee project
# altitude                                                   1200
# region                                                 southern
# producer                                  Mannya coffee project
# number_of_bags                                                6
# bag_weight                                                60 kg
# in_country_partner          Uganda Coffee Development Authority
# harvest_year                                               2013
# grading_date                                    June 27th, 2014
# owner_1                                   Mannya coffee project
# variety                                                     NaN
# processing_method                                           NaN
# aroma                                                      7.75
# flavor                                                     7.42
# aftertaste                                                 7.33
# acidity                                                    7.58
# body                                                       7.67
# balance                                                    7.58
# uniformity                                                 10.0
# clean_cup                                                  10.0
# sweetness                                                  7.67
# cupper_points                                               7.5
# total_cup_points                                           80.5
# moisture                                                   0.12
# category_one_defects                                          0
# quakers                                                     0.0
# color                                                     Green
# category_two_defects                                          1
# expiration                                      June 27th, 2015
# certification_body          Uganda Coffee Development Authority
# certification_address  e36d0270932c3b657e96b7b0278dfd85dc0fe743
# certification_contact  03077a1c6bac60e6f514691634a7f6eb5c85aae8
# unit_of_measurement                                           m
# altitude_low_meters                                      1200.0
# altitude_high_meters                                     1200.0
# altitude_mean_meters                                     1200.0
#
#                                                            1331  \
# species                                                 Robusta
# owner                                             andrew hetzel
# country_of_origin                                         India
# farm_name                                    sethuraman estates
# lot_number                                                  NaN
# mill                                                        NaN
# ico_number                                                  NaN
# company                                              cafemakers
# altitude                                                   750m
# region                                              chikmagalur
# producer                                         Nishant Gurjer
# number_of_bags                                              100
# bag_weight                                                 2 kg
# in_country_partner                 Specialty Coffee Association
# harvest_year                                               2014
# grading_date                                     May 19th, 2014
# owner_1                                           Andrew Hetzel
# variety                                                     NaN
# processing_method                                           NaN
# aroma                                                      7.67
# flavor                                                     7.67
# aftertaste                                                  7.5
# acidity                                                    7.33
# body                                                       7.58
# balance                                                     7.5
# uniformity                                                 10.0
# clean_cup                                                  10.0
# sweetness                                                  7.42
# cupper_points                                               7.5
# total_cup_points                                          80.17
# moisture                                                    0.0
# category_one_defects                                          0
# quakers                                                     0.0
# color                                              Bluish-Green
# category_two_defects                                          1
# expiration                                       May 19th, 2015
# certification_body                 Specialty Coffee Association
# certification_address  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# certification_contact  352d0cf7f3e9be14dad7df644ad65efc27605ae2
# unit_of_measurement                                           m
# altitude_low_meters                                       750.0
# altitude_high_meters                                      750.0
# altitude_mean_meters                                      750.0
#
#                                                            1332  \
# species                                                 Robusta
# owner                                             andrew hetzel
# country_of_origin                                         India
# farm_name                                    sethuraman estates
# lot_number                                                  NaN
# mill                                         sethuraman estates
# ico_number                                                  NaN
# company                                         cafemakers, llc
# altitude                                                   750m
# region                                              chikmagalur
# producer                                         Nishant Gurjer
# number_of_bags                                              250
# bag_weight                                                 2 kg
# in_country_partner                 Specialty Coffee Association
# harvest_year                                               2013
# grading_date                                    June 20th, 2013
# owner_1                                           Andrew Hetzel
# variety                                                     NaN
# processing_method                                 Natural / Dry
# aroma                                                      7.58
# flavor                                                     7.42
# aftertaste                                                 7.42
# acidity                                                    7.83
# body                                                       7.42
# balance                                                     7.5
# uniformity                                                 10.0
# clean_cup                                                  10.0
# sweetness                                                  7.42
# cupper_points                                              7.58
# total_cup_points                                          80.17
# moisture                                                    0.0
# category_one_defects                                          0
# quakers                                                     0.0
# color                                                     Green
# category_two_defects                                          0
# expiration                                      June 20th, 2014
# certification_body                 Specialty Coffee Association
# certification_address  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# certification_contact  352d0cf7f3e9be14dad7df644ad65efc27605ae2
# unit_of_measurement                                           m
# altitude_low_meters                                       750.0
# altitude_high_meters                                      750.0
# altitude_mean_meters                                      750.0
#
#                                                            1333  \
# species                                                 Robusta
# owner                                             andrew hetzel
# country_of_origin                                 United States
# farm_name                                    sethuraman estates
# lot_number                                                  NaN
# mill                                         sethuraman estates
# ico_number                                                  NaN
# company                                         cafemakers, llc
# altitude                                                  3000'
# region                                              chikmagalur
# producer                                     Sethuraman Estates
# number_of_bags                                              100
# bag_weight                                                 1 kg
# in_country_partner                 Specialty Coffee Association
# harvest_year                                               2012
# grading_date                                February 29th, 2012
# owner_1                                           Andrew Hetzel
# variety                                                  Arusha
# processing_method                                 Natural / Dry
# aroma                                                      7.92
# flavor                                                      7.5
# aftertaste                                                 7.42
# acidity                                                    7.42
# body                                                       7.42
# balance                                                    7.42
# uniformity                                                 9.33
# clean_cup                                                  10.0
# sweetness                                                  7.58
# cupper_points                                              7.33
# total_cup_points                                          79.33
# moisture                                                    0.0
# category_one_defects                                          0
# quakers                                                     0.0
# color                                                     Green
# category_two_defects                                          0
# expiration                                  February 28th, 2013
# certification_body                 Specialty Coffee Association
# certification_address  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# certification_contact  352d0cf7f3e9be14dad7df644ad65efc27605ae2
# unit_of_measurement                                           m
# altitude_low_meters                                      3000.0
# altitude_high_meters                                     3000.0
# altitude_mean_meters                                     3000.0
#
#                                                            1334  \
# species                                                 Robusta
# owner                                               luis robles
# country_of_origin                                       Ecuador
# farm_name                                             robustasa
# lot_number                                             Lavado 1
# mill                                                our own lab
# ico_number                                                  NaN
# company                                               robustasa
# altitude                                                    NaN
# region                                         san juan, playas
# producer                          Café Robusta del Ecuador S.A.
# number_of_bags                                                1
# bag_weight                                                 2 kg
# in_country_partner                 Specialty Coffee Association
# harvest_year                                               2016
# grading_date                                 January 19th, 2016
# owner_1                                             Luis Robles
# variety                                                     NaN
# processing_method                                           NaN
# aroma                                                      7.75
# flavor                                                     7.58
# aftertaste                                                 7.33
# acidity                                                    7.58
# body                                                       5.08
# balance                                                    7.83
# uniformity                                                 10.0
# clean_cup                                                  10.0
# sweetness                                                  7.75
# cupper_points                                              7.83
# total_cup_points                                          78.75
# moisture                                                    0.0
# category_one_defects                                          0
# quakers                                                     0.0
# color                                                Blue-Green
# category_two_defects                                          1
# expiration                                   January 18th, 2017
# certification_body                 Specialty Coffee Association
# certification_address  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# certification_contact  352d0cf7f3e9be14dad7df644ad65efc27605ae2
# unit_of_measurement                                           m
# altitude_low_meters                                         NaN
# altitude_high_meters                                        NaN
# altitude_mean_meters                                        NaN
#
#                                                            1335  \
# species                                                 Robusta
# owner                                               luis robles
# country_of_origin                                       Ecuador
# farm_name                                             robustasa
# lot_number                                             Lavado 3
# mill                                             own laboratory
# ico_number                                                  NaN
# company                                               robustasa
# altitude                                                     40
# region                                         san juan, playas
# producer                          Café Robusta del Ecuador S.A.
# number_of_bags                                                1
# bag_weight                                                 2 kg
# in_country_partner                 Specialty Coffee Association
# harvest_year                                               2016
# grading_date                                 January 19th, 2016
# owner_1                                             Luis Robles
# variety                                                     NaN
# processing_method                                           NaN
# aroma                                                       7.5
# flavor                                                     7.67
# aftertaste                                                 7.75
# acidity                                                    7.75
# body                                                       5.17
# balance                                                    5.25
# uniformity                                                 10.0
# clean_cup                                                  10.0
# sweetness                                                  8.42
# cupper_points                                              8.58
# total_cup_points                                          78.08
# moisture                                                    0.0
# category_one_defects                                          0
# quakers                                                     0.0
# color                                                Blue-Green
# category_two_defects                                          0
# expiration                                   January 18th, 2017
# certification_body                 Specialty Coffee Association
# certification_address  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# certification_contact  352d0cf7f3e9be14dad7df644ad65efc27605ae2
# unit_of_measurement                                           m
# altitude_low_meters                                        40.0
# altitude_high_meters                                       40.0
# altitude_mean_meters                                       40.0
#
#                                                            1336  \
# species                                                 Robusta
# owner                                               james moore
# country_of_origin                                 United States
# farm_name                                       fazenda cazengo
# lot_number                                                  NaN
# mill                                               cafe cazengo
# ico_number                                                  NaN
# company                                 global opportunity fund
# altitude                                             795 meters
# region                            kwanza norte province, angola
# producer                                           Cafe Cazengo
# number_of_bags                                                1
# bag_weight                                                 1 kg
# in_country_partner                 Specialty Coffee Association
# harvest_year                                               2014
# grading_date                                December 23rd, 2014
# owner_1                                             James Moore
# variety                                                     NaN
# processing_method                                 Natural / Dry
# aroma                                                      7.33
# flavor                                                     7.33
# aftertaste                                                 7.17
# acidity                                                    7.42
# body                                                        7.5
# balance                                                    7.17
# uniformity                                                 9.33
# clean_cup                                                  9.33
# sweetness                                                  7.42
# cupper_points                                              7.17
# total_cup_points                                          77.17
# moisture                                                    0.0
# category_one_defects                                          0
# quakers                                                     0.0
# color                                                       NaN
# category_two_defects                                          6
# expiration                                  December 23rd, 2015
# certification_body                 Specialty Coffee Association
# certification_address  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# certification_contact  352d0cf7f3e9be14dad7df644ad65efc27605ae2
# unit_of_measurement                                           m
# altitude_low_meters                                       795.0
# altitude_high_meters                                      795.0
# altitude_mean_meters                                      795.0
#
#                                                            1337  \
# species                                                 Robusta
# owner                                             cafe politico
# country_of_origin                                         India
# farm_name                                                   NaN
# lot_number                                                  NaN
# mill                                                        NaN
# ico_number                                    14-1118-2014-0087
# company                                           cafe politico
# altitude                                                    NaN
# region                                                      NaN
# producer                                                    NaN
# number_of_bags                                                1
# bag_weight                                                5 lbs
# in_country_partner                 Specialty Coffee Association
# harvest_year                                               2013
# grading_date                                  August 25th, 2014
# owner_1                                           Cafe Politico
# variety                                                     NaN
# processing_method                                 Natural / Dry
# aroma                                                      7.42
# flavor                                                     6.83
# aftertaste                                                 6.75
# acidity                                                    7.17
# body                                                       7.25
# balance                                                     7.0
# uniformity                                                 9.33
# clean_cup                                                  9.33
# sweetness                                                  7.08
# cupper_points                                              6.92
# total_cup_points                                          75.08
# moisture                                                    0.1
# category_one_defects                                         20
# quakers                                                     0.0
# color                                                     Green
# category_two_defects                                          1
# expiration                                    August 25th, 2015
# certification_body                 Specialty Coffee Association
# certification_address  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# certification_contact  352d0cf7f3e9be14dad7df644ad65efc27605ae2
# unit_of_measurement                                           m
# altitude_low_meters                                         NaN
# altitude_high_meters                                        NaN
# altitude_mean_meters                                        NaN
#
#                                                            1338
# species                                                 Robusta
# owner                                             cafe politico
# country_of_origin                                       Vietnam
# farm_name                                                   NaN
# lot_number                                                  NaN
# mill                                                        NaN
# ico_number                                                  NaN
# company                                           cafe politico
# altitude                                                    NaN
# region                                                      NaN
# producer                                                    NaN
# number_of_bags                                                1
# bag_weight                                                5 lbs
# in_country_partner                 Specialty Coffee Association
# harvest_year                                               2013
# grading_date                                  August 25th, 2014
# owner_1                                           Cafe Politico
# variety                                                     NaN
# processing_method                                 Natural / Dry
# aroma                                                      6.75
# flavor                                                     6.67
# aftertaste                                                  6.5
# acidity                                                    6.83
# body                                                       6.92
# balance                                                    6.83
# uniformity                                                 9.33
# clean_cup                                                  9.33
# sweetness                                                  6.67
# cupper_points                                              7.92
# total_cup_points                                          73.75
# moisture                                                   0.12
# category_one_defects                                         63
# quakers                                                     0.0
# color                                                       NaN
# category_two_defects                                          9
# expiration                                    August 25th, 2015
# certification_body                 Specialty Coffee Association
# certification_address  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# certification_contact  352d0cf7f3e9be14dad7df644ad65efc27605ae2
# unit_of_measurement                                           m
# altitude_low_meters                                         NaN
# altitude_high_meters                                        NaN
# altitude_mean_meters                                        NaN
#
# [43 rows x 1339 columns]

# %%
coffee_set.category_two_defects.value_counts()
# Out:
# category_two_defects
# 0     373
# 1     207
# 2     182
# 3     134
# 4     118
# 5      73
# 6      44
# 7      41
# 8      29
# 9      23
# 10     21
# 12     13
# 13      9
# 14      9
# 20      8
# 11      8
# 17      7
# 16      6
# 15      6
# 19      3
# 26      3
# 21      2
# 29      2
# 18      2
# 23      2
# 30      2
# 47      1
# 24      1
# 27      1
# 28      1
# 31      1
# 40      1
# 38      1
# 45      1
# 34      1
# 22      1
# 32      1
# 55      1
# Name: count, dtype: int64

# %% [markdown]
# ### Problem 4. Bag weight (1 point)
# What's up with the bag weights? Make all necessary changes to the column values. Don't forget to document your methods and assumptions.

# %% [markdown]
# Bag weight should be number, not string. Some values have the string 'kg' concataneted and this should be removed. Type should be chabged to int

# %%
coffee_set["bag_weight"].str.split().str[0]
# Out:
# 0       60
# 1       60
# 2        1
# 3       60
# 4       60
#         ..
# 1334     2
# 1335     2
# 1336     1
# 1337     5
# 1338     5
# Name: bag_weight, Length: 1339, dtype: object

# %%
coffee_set["bag_weight"] = coffee_set["bag_weight"].str.split(" ").str[0].astype(int)

# %%
coffee_set.bag_weight.dtype
# Out:
# dtype('int32')

# %% [markdown]
# ### Problem 5. Dates (1 point)
# This should remind you of problem 4 but it's slightly nastier. Fix the harvest years, document the process.
#
# While you're here, fix the expiration dates, and grading dates. Unlike the other column, these should be dates (`pd.to_datetime()` is your friend).

# %%
coffee_set.expiration.value_counts().unique
# Out:
# <bound method Series.unique of expiration
# July 11th, 2013        25
# December 26th, 2014    25
# June 6th, 2013         19
# August 30th, 2013      18
# July 26th, 2013        15
#                        ..
# March 8th, 2012         1
# May 11th, 2012          1
# December 1st, 2012      1
# April 27th, 2013        1
# December 23rd, 2015     1
# Name: count, Length: 566, dtype: int64>

# %%
#coffee_set["expiration"].astype('datetime64[ns]')
exp = pd.to_datetime(coffee_set["expiration"], format = "mixed")

# %%
grade = pd.to_datetime(coffee_set.grading_date, format = "mixed")

# %%
grade
# Out:
# 0      2015-04-04
# 1      2015-04-04
# 2      2010-05-31
# 3      2015-03-26
# 4      2015-04-04
#           ...
# 1334   2016-01-19
# 1335   2016-01-19
# 1336   2014-12-23
# 1337   2014-08-25
# 1338   2014-08-25
# Name: grading_date, Length: 1339, dtype: datetime64[ns]

# %%
coffee_set["expiration"] = pd.to_datetime(coffee_set["expiration"], format = "mixed")
coffee_set["grading_date"] = pd.to_datetime(coffee_set["grading_date"], format = "mixed")
coffee_set.harvest_year.value_counts().unique
# Out:
# <bound method Series.unique of harvest_year
# 2012                        354
# 2014                        233
# 2013                        181
# 2015                        129
# 2016                        124
# 2017                         70
# 2013/2014                    29
# 2015/2016                    28
# 2011                         26
# 2017 / 2018                  19
# 2014/2015                    19
# 2009/2010                    12
# 2010                         10
# 2010-2011                     6
# 2016 / 2017                   6
# 4T/10                         4
# March 2010                    3
# 2009-2010                     3
# Mayo a Julio                  3
# 4T/2010                       3
# Abril - Julio                 2
# January 2011                  2
# 2011/2012                     2
# 08/09 crop                    2
# December 2009-March 2010      1
# TEST                          1
# 4T72010                       1
# 2018                          1
# 1t/2011                       1
# 2016/2017                     1
# 3T/2011                       1
# Spring 2011 in Colombia.      1
# Abril - Julio /2011           1
# 4t/2011                       1
# 2009 / 2010                   1
# 47/2010                       1
# 2009 - 2010                   1
# August to December            1
# May-August                    1
# 4t/2010                       1
# 1T/2011                       1
# January Through April         1
# Fall 2009                     1
# Sept 2009 - April 2010        1
# mmm                           1
# 23 July 2010                  1
# Name: count, dtype: int64>

# %%
coffee_set["harvest_year"].str.count('/').sum()
# Out:
# 133.0

# %%
coffee_set["harvest_year"].str.extract('(\d+)').value_counts(dropna = False).unique
# Out:
# <bound method Series.unique of 2012    354
# 2014    252
# 2013    210
# 2015    157
# 2016    131
# 2017     89
# NaN      57
# 2011     32
# 2009     20
# 2010     19
# 4        10
# 1         2
# 08        2
# 2018      1
# 23        1
# 3         1
# 47        1
# Name: count, dtype: int64>

# %%
coffee_set["harvest_year"].str.extract('([1,2]\d{3})').value_counts(dropna = False).unique
# Out:
# <bound method Series.unique of 2012    354
# 2014    252
# 2013    210
# 2015    157
# 2016    131
# 2017     89
# NaN      63
# 2011     36
# 2010     26
# 2009     20
# 2018      1
# Name: count, dtype: int64>

# %%
coffee_set["harvest_year_tidy"] = coffee_set["harvest_year"].str.extract('([1,2]\d{3})')
coffee_set.columns
# Out:
# Index(['species', 'owner', 'country_of_origin', 'farm_name', 'lot_number',
#        'mill', 'ico_number', 'company', 'altitude', 'region', 'producer',
#        'number_of_bags', 'bag_weight', 'in_country_partner', 'harvest_year',
#        'grading_date', 'owner_1', 'variety', 'processing_method', 'aroma',
#        'flavor', 'aftertaste', 'acidity', 'body', 'balance', 'uniformity',
#        'clean_cup', 'sweetness', 'cupper_points', 'total_cup_points',
#        'moisture', 'category_one_defects', 'quakers', 'color',
#        'category_two_defects', 'expiration', 'certification_body',
#        'certification_address', 'certification_contact', 'unit_of_measurement',
#        'altitude_low_meters', 'altitude_high_meters', 'altitude_mean_meters',
#        'harvest_year_tidy'],
#       dtype='object')

# %%
coffee_set_year_tidy = coffee_set.drop(columns = ["harvest_year"])
coffee_set_year_tidy["harvest_year_tidy"]  = coffee_set_year_tidy["harvest_year_tidy"].astype('Int64')
coffee_set_year_tidy
# Out:
#       species                     owner country_of_origin  \
# 0     Arabica                 metad plc          Ethiopia
# 1     Arabica                 metad plc          Ethiopia
# 2     Arabica  grounds for health admin         Guatemala
# 3     Arabica       yidnekachew dabessa          Ethiopia
# 4     Arabica                 metad plc          Ethiopia
# ...       ...                       ...               ...
# 1334  Robusta               luis robles           Ecuador
# 1335  Robusta               luis robles           Ecuador
# 1336  Robusta               james moore     United States
# 1337  Robusta             cafe politico             India
# 1338  Robusta             cafe politico           Vietnam
#
#                                      farm_name lot_number            mill  \
# 0                                    metad plc        NaN       metad plc
# 1                                    metad plc        NaN       metad plc
# 2     san marcos barrancas "san cristobal cuch        NaN             NaN
# 3        yidnekachew dabessa coffee plantation        NaN         wolensu
# 4                                    metad plc        NaN       metad plc
# ...                                        ...        ...             ...
# 1334                                 robustasa   Lavado 1     our own lab
# 1335                                 robustasa   Lavado 3  own laboratory
# 1336                           fazenda cazengo        NaN    cafe cazengo
# 1337                                       NaN        NaN             NaN
# 1338                                       NaN        NaN             NaN
#
#              ico_number                                company       altitude  \
# 0             2014/2015      metad agricultural developmet plc      1950-2200
# 1             2014/2015      metad agricultural developmet plc      1950-2200
# 2                   NaN                                    NaN  1600 - 1800 m
# 3                   NaN  yidnekachew debessa coffee plantation      1800-2200
# 4             2014/2015      metad agricultural developmet plc      1950-2200
# ...                 ...                                    ...            ...
# 1334                NaN                              robustasa            NaN
# 1335                NaN                              robustasa             40
# 1336                NaN                global opportunity fund     795 meters
# 1337  14-1118-2014-0087                          cafe politico            NaN
# 1338                NaN                          cafe politico            NaN
#
#                              region  ... category_two_defects  expiration  \
# 0                      guji-hambela  ...                    0  2016-04-03
# 1                      guji-hambela  ...                    1  2016-04-03
# 2                               NaN  ...                    0  2011-05-31
# 3                            oromia  ...                    2  2016-03-25
# 4                      guji-hambela  ...                    2  2016-04-03
# ...                             ...  ...                  ...         ...
# 1334               san juan, playas  ...                    1  2017-01-18
# 1335               san juan, playas  ...                    0  2017-01-18
# 1336  kwanza norte province, angola  ...                    6  2015-12-23
# 1337                            NaN  ...                    1  2015-08-25
# 1338                            NaN  ...                    9  2015-08-25
#
#                       certification_body  \
# 0     METAD Agricultural Development plc
# 1     METAD Agricultural Development plc
# 2           Specialty Coffee Association
# 3     METAD Agricultural Development plc
# 4     METAD Agricultural Development plc
# ...                                  ...
# 1334        Specialty Coffee Association
# 1335        Specialty Coffee Association
# 1336        Specialty Coffee Association
# 1337        Specialty Coffee Association
# 1338        Specialty Coffee Association
#
#                          certification_address  \
# 0     309fcf77415a3661ae83e027f7e5f05dad786e44
# 1     309fcf77415a3661ae83e027f7e5f05dad786e44
# 2     36d0d00a3724338ba7937c52a378d085f2172daa
# 3     309fcf77415a3661ae83e027f7e5f05dad786e44
# 4     309fcf77415a3661ae83e027f7e5f05dad786e44
# ...                                        ...
# 1334  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1335  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1336  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1337  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
# 1338  ff7c18ad303d4b603ac3f8cff7e611ffc735e720
#
#                          certification_contact unit_of_measurement  \
# 0     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 1     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 2     0878a7d4b9d35ddbf0fe2ce69a2062cceb45a660                   m
# 3     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# 4     19fef5a731de2db57d16da10287413f5f99bc2dd                   m
# ...                                        ...                 ...
# 1334  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1335  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1336  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1337  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
# 1338  352d0cf7f3e9be14dad7df644ad65efc27605ae2                   m
#
#      altitude_low_meters altitude_high_meters  altitude_mean_meters  \
# 0                 1950.0               2200.0                2075.0
# 1                 1950.0               2200.0                2075.0
# 2                 1600.0               1800.0                1700.0
# 3                 1800.0               2200.0                2000.0
# 4                 1950.0               2200.0                2075.0
# ...                  ...                  ...                   ...
# 1334                 NaN                  NaN                   NaN
# 1335                40.0                 40.0                  40.0
# 1336               795.0                795.0                 795.0
# 1337                 NaN                  NaN                   NaN
# 1338                 NaN                  NaN                   NaN
#
#       harvest_year_tidy
# 0                  2014
# 1                  2014
# 2                  <NA>
# 3                  2014
# 4                  2014
# ...                 ...
# 1334               2016
# 1335               2016
# 1336               2014
# 1337               2013
# 1338               2013
#
# [1339 rows x 43 columns]

# %% [markdown]
# Harvest_year had different values in different formats. This feature has to specify only the year it should be datetime type. What i have notice was that some records had 2 different year. But they were only 10% from all, whit no enough data for any correlation with other feauture. Easiest way for me was to find first 4 numbers started with 2 and to edit the cells with different format.

# %%
#coffee_set_year_tidy.to_csv("data/")

# %%
years_coffee = coffee_set["harvest_year"].astype(int, errors = "ignore")
years_coffee.value_counts().unique
# Out:
# <bound method Series.unique of harvest_year
# 2012                        354
# 2014                        233
# 2013                        181
# 2015                        129
# 2016                        124
# 2017                         70
# 2013/2014                    29
# 2015/2016                    28
# 2011                         26
# 2017 / 2018                  19
# 2014/2015                    19
# 2009/2010                    12
# 2010                         10
# 2010-2011                     6
# 2016 / 2017                   6
# 4T/10                         4
# March 2010                    3
# 2009-2010                     3
# Mayo a Julio                  3
# 4T/2010                       3
# Abril - Julio                 2
# January 2011                  2
# 2011/2012                     2
# 08/09 crop                    2
# December 2009-March 2010      1
# TEST                          1
# 4T72010                       1
# 2018                          1
# 1t/2011                       1
# 2016/2017                     1
# 3T/2011                       1
# Spring 2011 in Colombia.      1
# Abril - Julio /2011           1
# 4t/2011                       1
# 2009 / 2010                   1
# 47/2010                       1
# 2009 - 2010                   1
# August to December            1
# May-August                    1
# 4t/2010                       1
# 1T/2011                       1
# January Through April         1
# Fall 2009                     1
# Sept 2009 - April 2010        1
# mmm                           1
# 23 July 2010                  1
# Name: count, dtype: int64>

# %% [markdown]
# ### Problem 6. Countries (1 point)
# How many coffees are there with unknown countries of origin? What can you do about them?

# %%
coffee_set_year_tidy["country_of_origin"].value_counts(dropna = False).unique
# Out:
# <bound method Series.unique of country_of_origin
# Mexico                          236
# Colombia                        183
# Guatemala                       181
# Brazil                          132
# Taiwan                           75
# United States (Hawaii)           73
# Honduras                         53
# Costa Rica                       51
# Ethiopia                         44
# Tanzania, United Republic Of     40
# Uganda                           36
# Thailand                         32
# Nicaragua                        26
# Kenya                            25
# El Salvador                      21
# Indonesia                        20
# China                            16
# India                            14
# Malawi                           11
# United States                    10
# Peru                             10
# Myanmar                           8
# Vietnam                           8
# Haiti                             6
# Philippines                       5
# United States (Puerto Rico)       4
# Panama                            4
# Ecuador                           3
# Laos                              3
# Burundi                           2
# Papua New Guinea                  1
# Rwanda                            1
# Zambia                            1
# Japan                             1
# Mauritius                         1
# Cote d?Ivoire                     1
# NaN                               1
# Name: count, dtype: int64>

# %% [markdown]
# There is one coffee with unknown country of origin. We can drop it.

# %%
coffee_set_year_tidy["country_of_origin"] = coffee_set_year_tidy["country_of_origin"].dropna()
coffee_set_year_tidy.loc[[1137]]
# Out:
#       species                         owner country_of_origin  \
# 1137  Arabica  jesus carlos cadena valdivia            Mexico
#
#                farm_name lot_number                                     mill  \
# 1137  finca huehuetecpan        NaN  cosautlan de carvajal, veracruz, méxico
#
#       ico_number                              company altitude    region  ...  \
# 1137  1104387103  cafetalera la asunción s.a. de c.v.     1250  veracruz  ...
#
#      category_two_defects  expiration  certification_body  \
# 1137                    0  2013-07-11             AMECAFE
#
#                          certification_address  \
# 1137  59e396ad6e22a1c22b248f958e1da2bd8af85272
#
#                          certification_contact unit_of_measurement  \
# 1137  0eb4ee5b3f47b20b049548a2fd1e7d4a2b70d0a7                   m
#
#      altitude_low_meters altitude_high_meters  altitude_mean_meters  \
# 1137              1250.0               1250.0                1250.0
#
#       harvest_year_tidy
# 1137               2012
#
# [1 rows x 43 columns]

# %% [markdown]
# ### Problem 7. Owners (1 point)
# There are two suspicious columns, named `Owner`, and `Owner.1` (they're likely called something different after you solved problem 3). Do something about them. Is there any link to `Producer`?

# %%
coffee_set_year_tidy.owner.value_counts().unique, coffee_set_year_tidy.owner_1.value_counts().unique, coffee_set_year_tidy.producer.value_counts().unique
# Out:
# (<bound method Series.unique of owner
#  juan luis alvarado romero           155
#  racafe & cia s.c.a                   60
#  exportadora de cafe condor s.a       54
#  kona pacific farmers cooperative     52
#  ipanema coffees                      50
#                                     ...
#  alvaro quiros perez                   1
#  olivia hernandez virves               1
#  finca las nieves                      1
#  pedro santos e silva                  1
#  james moore                           1
#  Name: count, Length: 315, dtype: int64>,
#  <bound method Series.unique of owner_1
#  Juan Luis Alvarado Romero           155
#  Racafe & Cia S.C.A                   60
#  Exportadora de Cafe Condor S.A       54
#  Kona Pacific Farmers Cooperative     52
#  Ipanema Coffees                      50
#                                     ...
#  ALVARO QUIROS PEREZ                   1
#  OLIVIA HERNANDEZ VIRVES               1
#  FINCA LAS NIEVES                      1
#  Pedro Santos e Silva                  1
#  James Moore                           1
#  Name: count, Length: 319, dtype: int64>,
#  <bound method Series.unique of producer
#  La Plata                           30
#  Ipanema Agrícola SA                22
#  Doi Tung Development Project       17
#  VARIOS                             12
#  Ipanema Agricola                   12
#                                     ..
#  Kucofa farmers group                1
#  GRUPO MEDINA                        1
#  COFFEE COMPANY / CAFECOL            1
#  ORLANDO ORTOZ / HIPOLITO TORRES     1
#  Cafe Cazengo                        1
#  Name: count, Length: 692, dtype: int64>)

# %%
coffee_set_year_tidy.owner.str.lower().compare(coffee_set_year_tidy.owner_1.str.lower())
# Out:
#                                   self                             other
# 219                         ceca, s.a.                         ceca,s.a.
# 392   federacion nacional de cafeteros  federación nacional de cafeteros
# 734                      klem organics                      klemorganics
# 919             lin, che-hao krude 林哲豪          lin, che-hao krude 林哲豪\n
# 961                      klem organics                      klemorganics
# 1083          cqi taiwan icp cqi台灣合作夥伴        cqi taiwan icp cqi台灣合作夥伴\n

# %% [markdown]
# #### Feature owner_1 is the same like owner and have with some errors. It is useless and will be droped.

# %%
coffee_set_year_tidy = coffee_set_year_tidy.drop(columns = ["owner_1"])

# %%
coffee_set_year_tidy.shape
# Out:
# (1339, 42)

# %%
coffee_set_year_tidy.owner.str.lower().compare(coffee_set_year_tidy.producer.str.lower())
# Out:
#                              self                                      other
# 2        grounds for health admin                                        NaN
# 3             yidnekachew dabessa      yidnekachew dabessa coffee plantation
# 5                       ji-ae ahn                                        NaN
# 6                   hugo valdivia                                        hvc
# 7     ethiopia commodity exchange  bazen agricultural & industrial dev't plc
# ...                           ...                                        ...
# 1334                  luis robles              café robusta del ecuador s.a.
# 1335                  luis robles              café robusta del ecuador s.a.
# 1336                  james moore                               cafe cazengo
# 1337                cafe politico                                        NaN
# 1338                cafe politico                                        NaN
#
# [1188 rows x 2 columns]

# %%
coffee_set_year_tidy.groupby("owner").producer.value_counts(dropna=False).to_frame().head(50)
# Out:
#                                                                           count
# owner                         producer
# acacia hills ltd              Acacia Hills Ltd                                1
# adam ciruli ye                Yunnan Louis Herbs R&D Center                   1
#                               Alicia's Farm                                   1
# adam kline                    NaN                                             3
# adriana torres rico quevedo   ADRIANA TORRES RICO QUEVEDO                     1
# afca                          Mzuzu Coffee Coop Union                         6
#                               NaN                                             4
#                               Mzuzu Coffee Planters Coop Union                2
#                               R.W.J. Wallace Ltd                              2
#                               Kawacom                                         1
#                               Mondul Coffee Estate                            1
#                               Mzuzu Coffee Coop Union                         1
# alejandro garcia palacios     MARTHA PALACIOS                                 2
#                               ALEJANDRO GARCÍA PALACIOS                       1
#                               MARIO GARCÍA                                    1
# alexandra katona-carroll      NaN                                             1
# alfredo bojalil               AGROINDUSTRIAS UNIDAS DE MEXICO SA DE CV        3
#                               OCTAVIO MOGUEL FARRERA                          3
#                               ERNST POHLENZ AGUILAR                           2
#                               SANTIAGO JOSE ARGUELLO CAMPOS                   1
#                               OLIVIA HERNANDEZ VIRUES                         1
#                               ANGEL GONZALES                                  1
#                               JULIAN ALBERTO URRUTIA MOYA                     1
#                               ARTURO LIEVANO MORENO                           1
#                               CARLOS ALBERTO GOMEZ                            1
#                               CECILIA AVILA CAMBEROS                          1
#                               EPIFANIO GARCIA DE MIGUEL                       1
#                               FRANCISCO J. CONTRERAS MARTINEZ DE ESCOBAR      1
#                               FRANCO COLORADO DOMINGUEZ                       1
#                               JORGE HERNANDEZ MONTEJO                         1
# almacafe                      NaN                                             1
# alvaro quiros perez           ALVARO QUIROS PEREZ, MIGUEL QUIROZ PEREZ        1
# amanda powers                 NaN                                             1
# amkeni gourmet coffee group   Amkeni Gourmet Coffee Group                     1
# ana gonzales                  various smallholders                            1
# andrea bernal                 NaN                                             1
# andreas kussmaul              Exportadora Café California                     2
#                               ECC                                             1
# andres martinez leon          ANDRES MARTINEZ LEON                            1
# andrew bowman                 FIECH                                           1
#                               Sol y Cafe                                      1
# andrew hetzel                 Nishant Gurjer                                  6
#                               Sethuraman Estates                              2
#                               Nishant Gurger                                  1
# andry simarmata               SMALL HOLDERS FARMER                            1
# angel oscar medina rodriguez  Juan Hermilo Sampieri                           1
# ankole coffee producers coop  Ankole coffee producers coop                    1
#                               Ankole coffee producers coop union Ltd          1
# armando luis pohlenz martinez ARMANDO LUIS POHLENZ MARTINEZ                   5
# artemio zapata tejeda         ARTEMIO ZAPATA TEJEDA                           1

# %%
coffee_set_year_tidy.groupby("producer").owner.value_counts(dropna=False).to_frame().head(60)
# Out:
#                                                                                                   count
# producer                                           owner
# -                                                  cqi taiwan icp cqi台灣合作夥伴                           1
#                                                    taylor winch (coffee) ltd.                         1
#                                                    juan luis alvarado romero                          1
# 1                                                  william ho                                         1
# ADONIS JOSE ORTEZ BELTRAN                          exportadora atlantic, s.a.                         2
# ADRIANA TORRES RICO QUEVEDO                        adriana torres rico quevedo                        1
# AGRICOLA EL PILAR, S.A.                            juan luis alvarado romero                          3
# AGRICOLA EL PILAR, SA.                             juan luis alvarado romero                          1
# AGRICOLA MONTE VERDE                               juan luis alvarado romero                          1
# AGRICOLA MONTE VERDE, S.A.                         juan luis alvarado romero                          4
# AGRICOLA NUEVA GRANADA, S.A                        juan luis alvarado romero                          1
# AGRICOLA NUEVA GRANADA, S.A.                       juan luis alvarado romero                          2
# AGRIPEC DE LA VEGA Y CIA.                          juan luis alvarado romero                          4
# AGROINDUSTRIAS CAFETALERAS                         juan luis alvarado romero                          1
# AGROINDUSTRIAS UNIDAS DE MEXICO SA DE CV           alfredo bojalil                                    3
# AGROPECUARIA QUIAGRAL                              juan luis alvarado romero                          8
# ALBERTA TEODORO ANALCO                             israel eduardo paz garcia                          1
# ALEJANDRO GARCÍA PALACIOS                          alejandro garcia palacios                          1
# ALFREDO MOISES CEJA                                montegrande                                        1
# ALVARO QUIROS PEREZ, MIGUEL QUIROZ PEREZ           alvaro quiros perez                                1
# AMADOR HERNANDEZ DIONICIO                          saul m. hernandez ramirez                          1
# AMANCIO DEL VALLE CARRILLO                         juan luis alvarado romero                          1
# AMILCAR LAPOLA                                     juan luis alvarado romero                          9
# AMIN JAVIER MOISES CEJA                            montegrande                                        1
# AMPCG                                              balam hinyula                                      1
# ANDRES MARTINEZ LEON                               andres martinez leon                               1
# ANGEL DE LEON                                      juan luis alvarado romero                          5
# ANGEL GONZALES                                     alfredo bojalil                                    1
# ANTON GAYO                                         pt.royal pacific indah international               1
# ANTONIO CORDOBA MURILLO                            eric jesus cordoba arroyo                          1
# AQUILINO GARCÍA RIAÑO                              israel eduardo paz garcia                          1
# ARMANDO GUTIEREZ GUZMÁN                            miguel cortes moreno                               1
# ARMANDO GUTIERREZ GUZMAN                           miguel cortes moreno                               2
# ARMANDO LUIS POHLENZ MARTINEZ                      armando luis pohlenz martinez                      5
# ARTEMIO ZAPATA TEJEDA                              artemio zapata tejeda                              1
# ARTURO LIEVANO MORENO                              alfredo bojalil                                    1
# ASOCIACION DE PERMACULTORES DE CUILCO (SANTOS L... juan luis alvarado romero                          1
# AVELINO CHAVEZ REYNA                               productos y servicios chilindron s.a. de c.v.      2
# AVILA MARTINEZ ADOLFO                              saul m. hernandez ramirez                          1
# Acacia Hills Ltd                                   acacia hills ltd                                   1
# Agricola Nueva Granada, S. A.                      juan luis alvarado romero                          1
# Agrotello Coop                                     rob stephen                                        1
# Aida Batlle                                        atlantic specialty coffee                          2
# Alfredo De Jesús López Pérez                       cqi q coffee sample representative                 1
# Alicia's Farm                                      adam ciruli ye                                     1
# Alvaro Resende Aguiar                              nucoffee                                           1
# Amkeni Gourmet Coffee Group                        amkeni gourmet coffee group                        1
# Andrea Galvão Noqueira                             nucoffee                                           1
# Ankole coffee producers coop                       ankole coffee producers coop                       1
# Ankole coffee producers coop union Ltd             ankole coffee producers coop                       1
# Antonio Batista Francisquine                       cafebras                                           1
# Antônio Pelucio                                    nucoffee                                           1
# Apollo Co., LTd.                                   royal base corporation                             1
# Apollo Co., Ltd.                                   royal base corporation                             1
# Arturo Aguirre                                     essencecoffee                                      1
# Asociacion de Productores de Cafe de la Region ... lusso lab                                          1
# Asociación Aldea Global Jinotega                   asociación aldea global jinotega                   1
# Asosyasyon Plantè Kafe Krètapen (APCAP) ;Asosya... myriam kaplan-pasternak                            1
# Aspinwall & CO. LTD                                joshua marsceau                                    1
# Assefa Belay Coffee Producer                       assefa belay coffee producer                       2

# %% [markdown]
# Producer have same dublicated names, because some of them are with lower and other with upper letters. I will make all letters lower to check final count. Also will remove spaces. The connection between owner and producer is one -> many.

# %%
coffee_set_year_tidy["producer"] = coffee_set_year_tidy["producer"].str.lower().dropna().str.strip()
coffee_set_year_tidy[coffee_set_year_tidy["producer"].str.isnumeric() == True].producer
# Out:
# 1269    1
# Name: producer, dtype: object

# %% [markdown]
# One of the value is numeric. We will check later if this observation is important.
# Next step is to make this feature category.

# %%
coffee_set_year_tidy.groupby("producer").owner.value_counts(dropna=False).to_frame()
# Out:
#                                               count
# producer          owner
# -                 cqi taiwan icp cqi台灣合作夥伴        1
#                   taylor winch (coffee) ltd.      1
#                   juan luis alvarado romero       1
# 1                 william ho                      1
# acacia hills ltd  acacia hills ltd                1
# ...                                             ...
# 陳勝樂0912326001     cqi taiwan icp cqi台灣合作夥伴        1
# 雅慕伊               cqi taiwan icp cqi台灣合作夥伴        1
# 黃素貞0939227229     cqi taiwan icp cqi台灣合作夥伴        1
# 黃美桃 huang mei tao lin, che-hao krude 林哲豪          1
# 黑咖啡道王憲備0912326001 cqi taiwan icp cqi台灣合作夥伴        1
#
# [685 rows x 1 columns]

# %% [markdown]
# Some names of Producers are the same with add some symbol or space.

# %%
coffee_set_year_tidy.producer.value_counts().head(60).sort_index()
# Out:
# producer
# -                                     3
# agricola monte verde, s.a.            4
# agripec de la vega y cia.             4
# agropecuaria quiagral                 8
# amilcar lapola                        9
# angel de leon                         5
# armando luis pohlenz martinez         5
# balbino ramirez flores                5
# beneficio la eva s.a.                 3
# chapultepec                           4
# coffeas co., ltd.                     3
# conquista/morito                      4
# coop                                  3
# cooperativa coaquil                   4
# coricafe blend                        3
# doi tung development project         17
# finca kassandra                       3
# finca medina                          6
# franklin dussan                       3
# franklin dussan / hipolito torres     5
# hacienda alto grande                  4
# huatusco                              3
# ipanema agricola                     12
# ipanema agricola s.a                 11
# ipanema agrícola sa                  22
# ipanema coffees                       5
# jesus ramirez                         7
# jorge leal                            5
# jose omar acosta                      9
# kawacom uganda ltd                    4
# kona pacific farmers cooperative      3
# la plata                             39
# luis rodriguez                        6
# manuel herrera juarez                 6
# manuel montero                        3
# margarita avila de nuyens             5
# maria rogeria costa pereira           4
# martin gutierrez                      8
# matsuzawa coffee                      3
# mzuzu coffee coop union               7
# nahun maldonado                       6
# nazareth dias pereira                 7
# nishant gurjer                        6
# omar acosta                           6
# otto becker                           5
# pablo enrique martinez gama           4
# reinerio zepeda                       9
# roberto monterroso                   10
# several                               9
# sidama coffee farmers coop. union     4
# siembras visión, s.a.                 4
# sipi organic coffee project           3
# taylor winch (t) ltd                  4
# tembo coffee company ltd              4
# union ramal santa cruz                5
# varios                               20
# varios productores                    3
# various                               3
# various small producers               6
# various smallholders                  3
# Name: count, dtype: int64

# %%
coffee_set_year_tidy["producer_tidy"] = coffee_set_year_tidy.producer.apply(lambda x: 
                                    str(x).split(",")[0] 
                                    )

# %%
def clean_text(text):
    text = text.strip()
    text = text.replace(' .', '.')
    if text.endswith('.'):
        text = text[:-1] 
    return text

# %%
coffee_set_year_tidy["producer_tidy"] = coffee_set_year_tidy["producer_tidy"].astype(str).apply(clean_text)

# %%
coffee_set_year_tidy.groupby("producer_tidy").owner.value_counts(dropna=False).to_frame().head(30)
# Out:
#                                                                              count
# producer_tidy                            owner
# -                                        cqi taiwan icp cqi台灣合作夥伴                1
#                                          taylor winch (coffee) ltd.              1
#                                          juan luis alvarado romero               1
# 1                                        william ho                              1
# acacia hills ltd                         acacia hills ltd                        1
# adonis jose ortez beltran                exportadora atlantic, s.a.              2
# adriana torres rico quevedo              adriana torres rico quevedo             1
# agricola el pilar                        juan luis alvarado romero               4
# agricola monte verde                     juan luis alvarado romero               5
# agricola nueva granada                   juan luis alvarado romero               4
# agripec de la vega y cia                 juan luis alvarado romero               4
# agroindustrias cafetaleras               juan luis alvarado romero               1
# agroindustrias unidas de mexico sa de cv alfredo bojalil                         3
# agropecuaria quiagral                    juan luis alvarado romero               8
# agrotello coop                           rob stephen                             1
# aida batlle                              atlantic specialty coffee               2
# alberta teodoro analco                   israel eduardo paz garcia               1
# alejandro garcía palacios                alejandro garcia palacios               1
# alfredo de jesús lópez pérez             cqi q coffee sample representative      1
# alfredo moises ceja                      montegrande                             1
# alicia's farm                            adam ciruli ye                          1
# alvaro quiros perez                      alvaro quiros perez                     1
# alvaro resende aguiar                    nucoffee                                1
# amador hernandez dionicio                saul m. hernandez ramirez               1
# amancio del valle carrillo               juan luis alvarado romero               1
# amilcar lapola                           juan luis alvarado romero               9
# amin javier moises ceja                  montegrande                             1
# amkeni gourmet coffee group              amkeni gourmet coffee group             1
# ampcg                                    balam hinyula                           1
# andrea galvão noqueira                   nucoffee                                1

# %%
coffee_set_year_tidy["producer_tidy"].astype("category")
# Out:
# 0                                   metad plc
# 1                                   metad plc
# 2                                         nan
# 3       yidnekachew dabessa coffee plantation
# 4                                   metad plc
#                         ...
# 1334             café robusta del ecuador s.a
# 1335             café robusta del ecuador s.a
# 1336                             cafe cazengo
# 1337                                      nan
# 1338                                      nan
# Name: producer_tidy, Length: 1339, dtype: category
# Categories (658, object): ['-', '1', 'acacia hills ltd', 'adonis jose ortez beltran', ..., '雅慕伊', '黃素貞0939227229', '黃美桃 huang mei tao', '黑咖啡道王憲備0912326001']

# %%
#coffee_set_year_tidy["producer"].apply(lambda x: convert(x, 'US7ASCII'))

# %%
#a lot of different problems with names in owner and producer

# %% [markdown]
# ### Problem 8. Coffee color by country and continent (1 point)
# Create a table which shows how many coffees of each color are there in every country. Leave the missing values as they are.
#
# **Note:** If you ask me, countries should be in rows, I prefer long tables much better than wide ones.
#
# Now do the same for continents. You know what continent each country is located in.

# %%
country_by_color = coffee_set_year_tidy.groupby(["country_of_origin", "color"]).agg(count = pd.NamedAgg(column = "color", aggfunc = "count"))
country_by_color = country_by_color.pivot_table(index = ["country_of_origin"], columns = "color", values = "count")
country_by_color = country_by_color.rename_axis(index=None, columns=None)
country_by_color.columns = country_by_color.columns.str.lower()
country_by_color.index =  country_by_color.index.str.lower()
country_by_color
# Out:
#                               blue-green  bluish-green  green
# brazil                              14.0          12.0   92.0
# burundi                              NaN           NaN    1.0
# china                                NaN           NaN   16.0
# colombia                             8.0           8.0  118.0
# costa rica                          10.0           9.0   28.0
# cote d?ivoire                        NaN           1.0    NaN
# ecuador                              2.0           1.0    NaN
# el salvador                          2.0           2.0    9.0
# ethiopia                             NaN           2.0   15.0
# guatemala                            2.0           7.0  159.0
# haiti                                1.0           1.0    2.0
# honduras                             3.0           2.0   47.0
# india                                1.0           2.0   10.0
# indonesia                            4.0           3.0    6.0
# japan                                NaN           NaN    1.0
# kenya                                3.0           6.0   14.0
# laos                                 1.0           1.0    1.0
# malawi                               1.0           4.0    6.0
# mauritius                            NaN           NaN    1.0
# mexico                               7.0           7.0  156.0
# myanmar                              NaN           NaN    7.0
# nicaragua                            NaN           2.0   19.0
# panama                               NaN           1.0    2.0
# papua new guinea                     NaN           1.0    NaN
# peru                                 NaN           2.0    6.0
# philippines                          1.0           1.0    2.0
# rwanda                               NaN           1.0    NaN
# taiwan                              14.0           5.0   50.0
# tanzania, united republic of         NaN           7.0   32.0
# thailand                             3.0           7.0   10.0
# uganda                               2.0           1.0   32.0
# united states                        NaN           NaN    1.0
# united states (hawaii)               6.0          16.0   21.0
# united states (puerto rico)          NaN           1.0    3.0
# vietnam                              NaN           1.0    3.0

# %% [markdown]
# ### Problem 9. Ratings (1 point)
# The columns `Aroma`, `Flavor`, etc., up to `Moisture` represent subjective ratings. Explore them. Show the means and range; draw histograms and / or boxplots as needed. You can even try correlations if you want. What's up with all those ratings?

# %% [markdown]
# ### Problem 10. High-level errors (1 point)
# Check the countries against region names, altitudes, and companies. Are there any discrepancies (e.g. human errors, like a region not matching the country)? Take a look at the (cleaned) altitudes; there has been a lot of preprocessing done to them. Was it done correctly?

# %% [markdown]
# ### * Problem 11. Clean and explore at will
# The dataset claimed to be clean, but we were able to discover a lot of things to fix and do better.
#
# Play around with the data as much as you wish, and if you find variables to tidy up and clean - by all means, do that!
