# %%
# %matplotlib inline
# %pip install imagehash
# Out:
# Requirement already satisfied: imagehash in c:\users\nushi\anaconda3\lib\site-packages (4.3.1)
# Requirement already satisfied: PyWavelets in c:\users\nushi\anaconda3\lib\site-packages (from imagehash) (1.5.0)
# Requirement already satisfied: numpy in c:\users\nushi\anaconda3\lib\site-packages (from imagehash) (1.26.4)
# Requirement already satisfied: pillow in c:\users\nushi\anaconda3\lib\site-packages (from imagehash) (10.2.0)
# Requirement already satisfied: scipy in c:\users\nushi\anaconda3\lib\site-packages (from imagehash) (1.11.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import imread, imread_collection, imshow, imshow_collection
from scipy.signal import convolve2d
from scipy.fft import fft2,fftshift
from skimage.filters import threshold_otsu
from skimage.transform import resize, rescale, rotate
import os
import ast
from collections import Counter
from PIL import Image
import imagehash
# Out:
# C:\Users\nushi\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
#   "class": algorithms.Blowfish,

# %% [markdown]
# # Working with Images Lab
# ## Information retrieval, preprocessing, and feature extraction

# %% [markdown]
# In this lab, you'll work with images of felines (cats), which have been classified according to their taxonomy. Each subfolder contains images of a particular species. The dataset is located [here](https://www.kaggle.com/datasets/datahmifitb/felis-taxonomy-image-classification) but it's also provided to you in the `data/` folder.

# %% [markdown]
# ### Problem 1. Some exploration (1 point)
# How many types of cats are there? How many images do we have of each? What is a typical image size? Are there any outliers in size?

# %%
cat_collection = imread_collection("data/*")

# %%
cat_collection2 = imread_collection("data/*/*")

# %%
cat_collection2[0]
# Out:
# array([[[153, 119,  81],
#         [153, 119,  81],
#         [153, 119,  81],
#         ...,
#         [128, 107,  64],
#         [128, 107,  64],
#         [129, 108,  65]],
#
#        [[153, 119,  81],
#         [153, 119,  81],
#         [153, 119,  81],
#         ...,
#         [128, 107,  64],
#         [128, 107,  64],
#         [129, 108,  65]],
#
#        [[153, 119,  81],
#         [153, 119,  81],
#         [153, 119,  81],
#         ...,
#         [129, 108,  65],
#         [128, 107,  64],
#         [129, 108,  65]],
#
#        ...,
#
#        [[116, 116, 116],
#         [250, 250, 250],
#         [252, 252, 252],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[116, 116, 116],
#         [250, 250, 250],
#         [252, 252, 252],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[116, 116, 116],
#         [250, 250, 250],
#         [252, 252, 252],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
len(cat_collection)
# Out:
# 7

# %%
arr = os.listdir("data")

# %%
subdirectories = [file.path for file in os.scandir("data/") if file.is_dir()]

# %%
arr, subdirectories
# Out:
# (['african-wildcat',
#   'blackfoot-cat',
#   'chinese-mountain-cat',
#   'domestic-cat',
#   'european-wildcat',
#   'jungle-cat',
#   'sand-cat'],
#  ['data/african-wildcat',
#   'data/blackfoot-cat',
#   'data/chinese-mountain-cat',
#   'data/domestic-cat',
#   'data/european-wildcat',
#   'data/jungle-cat',
#   'data/sand-cat'])

# %%
# for item in arr:
#     # Check if the item is a directory
#     if os.path.isdir(os.path.join("data", item)):
#         collection = imread_collection(path)
#         exec("item = collection")

# %%
for folder in range(0, len(arr)-1):
     path = "data/" + arr[folder] + "/*"
     print(arr[folder], len(imread_collection(path)))
# Out:
# african-wildcat 91
# blackfoot-cat 79
# chinese-mountain-cat 42
# domestic-cat 64
# european-wildcat 85
# jungle-cat 86

# %%
subdirectories_names = [os.path.join("data", d) for d in os.listdir("data") if os.path.isdir(os.path.join("data", d))]
subdirectories_names
# Out:
# ['data\\african-wildcat',
#  'data\\blackfoot-cat',
#  'data\\chinese-mountain-cat',
#  'data\\domestic-cat',
#  'data\\european-wildcat',
#  'data\\jungle-cat',
#  'data\\sand-cat']

# %%
blackfoot_cats = imread_collection("data/blackfoot-cat/*")
jungle_cats = imread_collection("data/jungle-cat/*")
chinese_mountain_cats = imread_collection("data/chinese-mountain-cat/*")
sand_cats = imread_collection("data/sand-cat/*")
domestic_cats = imread_collection("data/domestic-cat/*")
african_wildcats = imread_collection("data/african-wildcat/*")
european_wildcats = imread_collection("data/european-wildcat/*")

# %%
blackfoot_size =[ blackfoot_cats[i].shape for i in range(0, len(blackfoot_cats))]
blackfoot_type_size = Counter(blackfoot_size)
jungle_size =[ jungle_cats[i].shape for i in range(0, len(jungle_cats))]
jungle_type_size = Counter(jungle_size)
chinese_mountain_size =[ chinese_mountain_cats[i].shape for i in range(0, len(chinese_mountain_cats))]
chinese_mountain_type_size = Counter(chinese_mountain_size)
sand_size =[ sand_cats[i].shape for i in range(0, len(sand_cats))]
sand_type_size = Counter(sand_size)
domestic_size =[domestic_cats[i].shape for i in range(0, len(domestic_cats))]
domestic_type_size = Counter(domestic_size)
african_size =[african_wildcats[i].shape for i in range(0, len(african_wildcats))]
african_type_size = Counter(african_size)
european_size =[european_wildcats[i].shape for i in range(0, len(european_wildcats))]
european_type_size = Counter(european_size)

# %%
blackfoot_type_size.most_common(5), jungle_type_size.most_common(5), chinese_mountain_type_size.most_common(5), sand_type_size.most_common(5), domestic_type_size.most_common(5), african_type_size.most_common(5), european_type_size.most_common(5)
# Out:
# ([((183, 275, 3), 11),
#   ((275, 183, 3), 7),
#   ((276, 183, 3), 5),
#   ((192, 262, 3), 4),
#   ((183, 276, 3), 3)],
#  [((183, 275, 3), 20),
#   ((194, 259, 3), 9),
#   ((275, 183, 3), 4),
#   ((201, 251, 3), 4),
#   ((187, 270, 3), 3)],
#  [((500, 800, 3), 4),
#   ((183, 275, 3), 4),
#   ((858, 1280, 3), 2),
#   ((477, 636, 3), 2),
#   ((3000, 4000, 3), 2)],
#  [((183, 275, 3), 22),
#   ((194, 259, 3), 8),
#   ((225, 225, 3), 6),
#   ((201, 251, 3), 2),
#   ((259, 194, 3), 2)],
#  [((183, 275, 3), 22),
#   ((225, 225, 3), 6),
#   ((194, 259, 3), 6),
#   ((190, 265, 3), 3),
#   ((200, 252, 3), 2)],
#  [((183, 275, 3), 25),
#   ((192, 262, 3), 6),
#   ((225, 225, 3), 5),
#   ((168, 300, 3), 5),
#   ((194, 259, 3), 4)],
#  [((1333, 2000, 3), 4),
#   ((183, 275, 3), 4),
#   ((866, 1300, 3), 3),
#   ((280, 390, 3), 3),
#   ((600, 800, 3), 3)])

# %%
# for index in range(0, len(blackfoot_type_size)):
#     print(blackfoot_type_size[index].key, blackfoot_type_size[index].value)
blackfoot_type_once = [key for key,value in blackfoot_type_size.items() if value ==1 ]
blackfoot_type_once
# Out:
# [(267, 189, 3),
#  (182, 277, 3),
#  (211, 239, 3),
#  (195, 259, 3),
#  (201, 251, 3),
#  (243, 207, 3),
#  (199, 253, 3),
#  (194, 259, 3),
#  (278, 182, 3),
#  (176, 287, 3),
#  (194, 260, 3),
#  (175, 220, 3),
#  (167, 302, 3),
#  (274, 184, 3),
#  (181, 278, 3),
#  (181, 279, 3),
#  (196, 257, 3),
#  (184, 274, 3),
#  (128, 250, 3),
#  (169, 299, 3),
#  (276, 182, 3),
#  (203, 249, 3),
#  (177, 284, 3),
#  (184, 275, 3),
#  (214, 235, 3),
#  (182, 278, 3),
#  (273, 184, 3),
#  (189, 267, 3),
#  (210, 240, 3),
#  (168, 299, 3),
#  (223, 226, 3)]

# %%
blackfoot_cats_reds = [image.ravel().sum()/1000 for image in blackfoot_cats]
plt.hist(blackfoot_cats_reds, bins = 50)

plt.xlabel("Pixel value/1000")
plt.ylabel("Count")

plt.show()

# %%
sizes = []
size_dict = {}
for dirpath, dirnames, filenames in os.walk("data"):
    for filename in filenames:
        img_path = os.path.join(dirpath, filename)
        size = os.path.getsize(img_path)
        sizes.append(size/1000)
        size_dict[img_path] = size
        
plt.hist(sizes, bins = 10)

plt.xlabel("Image size (bytes)")
plt.ylabel("Count")
plt.show()

# %%
for path, size in size_dict.items():
    if size/1000 > 600:
        print(path, size)
# Out:
# data\chinese-mountain-cat\ch (14).jpg 1489457
# data\chinese-mountain-cat\ch (19).jpg 1399835
# data\chinese-mountain-cat\ch (7).jpg 733577
# data\chinese-mountain-cat\.ipynb_checkpoints\ch (19)-checkpoint.jpg 1399835

# %% [markdown]
# #### There are 7 types of cats: Blackfoot, Jungle, Chinese mountain, Sand, Domestic and African cat.
# Blackfoot have 79 images, Jungle have 86 images, Chinese mountain have 42 images, Sand - 72 images, Domestic - 64 images, African - 91 images. The most typical image size is 183, 275,3. There are outliers images as we can see above - chinese-mountain-cat/ch (19).jpg,data/chinese-mountain-cat/ch (14).jpg and data/chinese-mountain-cat/ch (14).jpg

# %% [markdown]
# ### Problem 2. Duplicat(e)s (1 point)
# Find a way to filter out (remove) identical images. I would recommnend using file hashes, but there are many approaches. Keep in mind that during file saving, recompression, etc., a lot of artifacts can change the file content (bytes), but not visually.

# %%
for dir_s in subdirectories:
    print(os.listdir(dir_s))
# Out:
# ['af (1).jpg', 'af (10).jpg', 'af (11).jpg', 'af (12).jpg', 'af (13).jpg', 'af (14).jpg', 'af (15).jpg', 'af (16).jpg', 'af (17).jpg', 'af (18).jpg', 'af (19).jpg', 'af (2).jpg', 'af (20).jpg', 'af (21).jpg', 'af (22).jpg', 'af (23).jpg', 'af (24).jpg', 'af (25).jpg', 'af (26).jpg', 'af (27).jpg', 'af (28).jpg', 'af (29).jpg', 'af (3).jpg', 'af (30).jpg', 'af (31).jpg', 'af (32).jpg', 'af (33).jpg', 'af (34).jpg', 'af (35).jpg', 'af (36).jpg', 'af (37).jpg', 'af (38).jpg', 'af (39).jpg', 'af (4).jpg', 'af (40).jpg', 'af (41).jpg', 'af (42).jpg', 'af (43).jpg', 'af (44).jpg', 'af (45).jpg', 'af (46).jpg', 'af (47).jpg', 'af (48).jpg', 'af (49).jpg', 'af (5).jpg', 'af (50).jpg', 'af (51).jpg', 'af (52).jpg', 'af (53).jpg', 'af (54).jpg', 'af (55).jpg', 'af (56).jpg', 'af (57).jpg', 'af (58).jpg', 'af (59).jpg', 'af (6).jpg', 'af (60).jpg', 'af (61).jpg', 'af (62).jpg', 'af (63).jpg', 'af (64).jpg', 'af (65).jpg', 'af (66).jpg', 'af (67).jpg', 'af (68).jpg', 'af (69).jpg', 'af (7).jpg', 'af (70).jpg', 'af (71).jpg', 'af (72).jpg', 'af (73).jpg', 'af (74).jpg', 'af (75).jpg', 'af (76).jpg', 'af (77).jpg', 'af (78).jpg', 'af (79).jpg', 'af (8).jpg', 'af (80).jpg', 'af (81).jpg', 'af (82).jpg', 'af (83).jpg', 'af (84).jpg', 'af (85).jpg', 'af (86).jpg', 'af (87).jpg', 'af (88).jpg', 'af (89).jpg', 'af (9).jpg', 'af (90).jpg', 'af (91).jpg']
# ['bc (1).jpg', 'bc (10).jpg', 'bc (11).jpg', 'bc (12).jpg', 'bc (13).jpg', 'bc (14).jpg', 'bc (15).jpg', 'bc (16).jpg', 'bc (17).jpg', 'bc (18).jpg', 'bc (19).jpg', 'bc (2).jpg', 'bc (20).jpg', 'bc (21).jpg', 'bc (22).jpg', 'bc (23).jpg', 'bc (24).jpg', 'bc (25).jpg', 'bc (26).jpg', 'bc (27).jpg', 'bc (28).jpg', 'bc (29).jpg', 'bc (3).jpg', 'bc (30).jpg', 'bc (31).jpg', 'bc (32).jpg', 'bc (33).jpg', 'bc (34).jpg', 'bc (35).jpg', 'bc (36).jpg', 'bc (37).jpg', 'bc (38).jpg', 'bc (39).jpg', 'bc (4).jpg', 'bc (40).jpg', 'bc (41).jpg', 'bc (42).jpg', 'bc (43).jpg', 'bc (44).jpg', 'bc (45).jpg', 'bc (46).jpg', 'bc (47).jpg', 'bc (48).jpg', 'bc (49).jpg', 'bc (5).jpg', 'bc (50).jpg', 'bc (51).jpg', 'bc (52).jpg', 'bc (53).jpg', 'bc (54).jpg', 'bc (55).jpg', 'bc (56).jpg', 'bc (57).jpg', 'bc (58).jpg', 'bc (59).jpg', 'bc (6).jpg', 'bc (60).jpg', 'bc (61).jpg', 'bc (62).jpg', 'bc (63).jpg', 'bc (64).jpg', 'bc (65).jpg', 'bc (66).jpg', 'bc (67).jpg', 'bc (68).jpg', 'bc (69).jpg', 'bc (7).jpg', 'bc (70).jpg', 'bc (71).jpg', 'bc (72).jpg', 'bc (73).jpg', 'bc (74).jpg', 'bc (75).jpg', 'bc (76).jpg', 'bc (77).jpg', 'bc (78).jpg', 'bc (79).jpg', 'bc (8).jpg', 'bc (9).jpg']
# ['.ipynb_checkpoints', 'ch (1).jpg', 'ch (10).jpg', 'ch (11).jpg', 'ch (12).jpg', 'ch (13).jpg', 'ch (14).jpg', 'ch (15).jpg', 'ch (16).jpg', 'ch (17).jpg', 'ch (18).jpg', 'ch (19).jpg', 'ch (2).jpg', 'ch (20).jpg', 'ch (21).jpg', 'ch (22).jpg', 'ch (23).jpg', 'ch (24).jpg', 'ch (25).jpg', 'ch (26).jpg', 'ch (27).jpg', 'ch (28).jpg', 'ch (29).jpg', 'ch (3).jpg', 'ch (30).jpg', 'ch (31).jpg', 'ch (32).jpg', 'ch (33).jpg', 'ch (34).jpg', 'ch (35).jpg', 'ch (36).jpg', 'ch (37).jpg', 'ch (38).jpg', 'ch (39).jpg', 'ch (4).jpg', 'ch (40).jpg', 'ch (41).jpg', 'ch (42).jpg', 'ch (5).jpg', 'ch (6).jpg', 'ch (7).jpg', 'ch (8).jpg', 'ch (9).jpg']
# ['dc (1).jpg', 'dc (10).jpg', 'dc (11).jpg', 'dc (12).jpg', 'dc (13).jpg', 'dc (14).jpg', 'dc (15).jpg', 'dc (16).jpg', 'dc (17).jpg', 'dc (18).jpg', 'dc (19).jpg', 'dc (2).jpg', 'dc (20).jpg', 'dc (21).jpg', 'dc (22).jpg', 'dc (23).jpg', 'dc (24).jpg', 'dc (25).jpg', 'dc (26).jpg', 'dc (27).jpg', 'dc (28).jpg', 'dc (29).jpg', 'dc (3).jpg', 'dc (30).jpg', 'dc (31).jpg', 'dc (32).jpg', 'dc (33).jpg', 'dc (34).jpg', 'dc (35).jpg', 'dc (36).jpg', 'dc (37).jpg', 'dc (38).jpg', 'dc (39).jpg', 'dc (4).jpg', 'dc (40).jpg', 'dc (41).jpg', 'dc (42).jpg', 'dc (43).jpg', 'dc (44).jpg', 'dc (45).jpg', 'dc (46).jpg', 'dc (47).jpg', 'dc (48).jpg', 'dc (49).jpg', 'dc (5).jpg', 'dc (50).jpg', 'dc (51).jpg', 'dc (52).jpg', 'dc (53).jpg', 'dc (54).jpg', 'dc (55).jpg', 'dc (56).jpg', 'dc (57).jpg', 'dc (58).jpg', 'dc (59).jpg', 'dc (6).jpg', 'dc (60).jpg', 'dc (61).jpg', 'dc (62).jpg', 'dc (63).jpg', 'dc (64).jpg', 'dc (7).jpg', 'dc (8).jpg', 'dc (9).jpg']
# ['eu (1).jpg', 'eu (10).jpg', 'eu (11).jpg', 'eu (12).jpg', 'eu (13).jpg', 'eu (14).jpg', 'eu (15).jpg', 'eu (16).jpg', 'eu (17).jpg', 'eu (18).jpg', 'eu (19).jpg', 'eu (2).jpg', 'eu (20).jpg', 'eu (21).jpg', 'eu (22).jpg', 'eu (23).jpg', 'eu (24).jpg', 'eu (25).jpg', 'eu (26).jpg', 'eu (27).jpg', 'eu (28).jpg', 'eu (29).jpg', 'eu (3
# ['.ipynb_checkpoints', 'sd (1).jpg', 'sd (10).jpg', 'sd (11).jpg', 'sd (12).jpg', 'sd (13).jpg', 'sd (14).jpg', 'sd (15).jpg', 'sd (16).jpg', 'sd (17).jpg', 'sd (18).jpg', 'sd (19).jpg', 'sd (2).jpg', 'sd (20).jpg', 'sd (21).jpg', 'sd (22).jpg', 'sd (23).jpg', 'sd (24).jpg', 'sd (25).jpg', 'sd (26).jpg', 'sd (27).jpg', 'sd (28).jpg', 'sd (29).jpg', 'sd (3).jpg', 'sd (30).jpg', 'sd (31).jpg', 'sd (32).jpg', 'sd (33).jpg', 'sd (34).jpg', 'sd (35).jpg', 'sd (36).jpg', 'sd (37).jpg', 'sd (38).jpg', 'sd (39).jpg', 'sd (4).jpg', 'sd (40).jpg', 'sd (41).jpg', 'sd (42).jpg', 'sd (43).jpg', 'sd (44).jpg', 'sd (45).jpg', 'sd (46).jpg', 'sd (47).jpg', 'sd (48).jpg', 'sd (49).jpg', 'sd (5).jpg', 'sd (50).jpg', 'sd (51).jpg', 'sd (52).jpg', 'sd (53).jpg', 'sd (54).jpg', 'sd (55).jpg', 'sd (56).jpg', 'sd (57).jpg', 'sd (58).jpg', 'sd (59).jpg', 'sd (6).jpg', 'sd (60).jpg', 'sd (61).jpg', 'sd (62).jpg', 'sd (63).jpg', 'sd (64).jpg', 'sd (65).jpg', 'sd (66).jpg', 'sd (67).jpg', 'sd (68).jpg', 'sd (69).jpg', 'sd (7).jpg', 'sd (70).jpg', 'sd (71).jpg', 'sd (72).jpg', 'sd (8).jpg', 'sd (9).jpg']

# %%
hashes = {}
duplicates = []
space_saved = 0
for cat_directory in subdirectories:
    files_img = os.listdir(cat_directory)
    for file in files_img:
        path_image = os.path.join(cat_directory, file)
        if os.path.exists(path_image):
           with Image.open(os.path.join(cat_directory,file)) as img:
               temp_hash = imagehash.average_hash(img, hash_size = 8)
               print(path_image, temp_hash)
               if temp_hash in hashes: 
                   duplicates.append(path_image)
               else:
                    hashes[temp_hash] = file
   
            
        # if len(duplicates) != 0:
        #     for duplicate in duplicates:
        #         space_saved += os.path.getsize(os.path.join("data",duplicate)) 
        #         print(os.path.join("data",duplicate))
        #         #os.remove(os.path.join(cat_directory,duplicate))
        #         print("\n\nYou saved {} mb of Space!".format(round(space_saved/1000000),2))
# Out:
# data/african-wildcat\af (1).jpg fcebe0f0e8e800ff
# data/african-wildcat\af (10).jpg f0fcb8f8f8801027
# data/african-wildcat\af (11).jpg ffffe1f0f9e8e800
# data/african-wildcat\af (12).jpg 7174bf1f1c1ddf00
# data/african-wildcat\af (13).jpg 020f81819b3b1fbf
# data/african-wildcat\af (14).jpg 0000303c1effffff
# data/african-wildcat\af (15).jpg 1e7ffcf0f071f138
# data/jungle-cat\jg (83).jpg 002472347cfbf5f8
# data/jungle-cat\jg (84).jpg ffff83c3e3c181ff
# data/jungle-cat\jg (85).jpg 0dfbff1f03070eff
# data/jungle-cat\jg (86).jpg 10183838787fffdf
# data/jungle-cat\jg (9).jpg ffff838181990be7
# data/sand-cat\sd (1).jpg e0f0fcfc1c1c1800
# data/sand-cat\sd (10).jpg 1fe7c7470707077f
# data/sand-cat\sd (11).jpg 2030787cfe4e0404
# data/sand-cat\sd (12).jpg 061e76363e3e1f0d
# data/sand-cat\sd (13).jpg 000e3e3e2c80f3ff
# data/sand-cat\sd (14).jpg 00a69fc7dfbf0321
# data/sand-cat\sd (15).jpg ff7f773c18183000
# data/sand-cat\sd (16).jpg 7cfe7f0f35240480
# data/sand-cat\sd (17).jpg 0f7f3ff0f0d058f8
# data/sand-cat\sd (18).jpg 00303c3c1edefffa
# data/sand-cat\sd (19).jpg 1b0307060e1f1e2f
# data/sand-cat\sd (2).jpg 00040c0e7e199fff
# data/sand-cat\sd (20).jpg 3c349cece22e1f3d
# data/sand-cat\sd (21).jpg 637d7c7c7c3c3c3c
# data/sand-cat\sd (22).jpg ffe30020000affff
# data/sand-cat\sd (23).jpg ffff37384040cf50
# data/sand-cat\sd (24).jpg ffe30000000affff
# data/sand-cat\sd (25).jpg 8020307e3c7e5c00
# data/sand-cat\sd (26).jpg b6861e6e363c38e0
# data/sand-cat\sd (27).jpg 004460791c9ee3fe
# data/sand-cat\sd (28).jpg 002c3c3cbc710113
# data/sand-cat\sd (29).jpg 0098bcbeb676983f
# data/sand-cat\sd (3).jpg fffde000020203e0
# data/sand-cat\sd (30).jpg 00042cfcfcf8f8c3
# data/sand-cat\sd (31).jpg 0706fcf8731f0f00
# data/sand-cat\sd (32).jpg fffff83c7e0e0e00
# data/sand-cat\sd (33).jpg 043e7e7e39333c00
# data/sand-cat\sd (34).jpg 0000181819d3f7f7
# data/sand-cat\sd (35).jpg fe9fdfc783112384
# data/sand-cat\sd (36).jpg fefcfcf8f8780800
# data/sand-cat\sd (37).jpg 10101c1e0f0f0eee
# data/sand-cat\sd (38).jpg c12e06e4e6f4f0fb
# data/sand-cat\sd (39).jpg 7f7f3f3c180cf010
# data/sand-cat\sd (4).jpg 00f0fc7c3c3c3ce0
# data/sand-cat\sd (40).jpg ff9fcf0d1f174446
# data/sand-cat\sd (41).jpg 00603c3ce4c8c6c6
# data/sand-cat\sd (42).jpg a0b8f878781ff060
# data/sand-cat\sd (43).jpg 7f7f3e7818bc1000
# data/sand-cat\sd (44).jpg 637d7c7c7c3c3c3c
# data/sand-cat\sd (45).jpg 00e0f0fcfcf8f080
# data/sand-cat\sd (46).jpg 013c3e1c00c0fcde
# data/sand-cat\sd (47).jpg 11183c737b3b3f07
# data/sand-cat\sd (48).jpg c0ecfcececcc0c0f
# data/sand-cat\sd (49).jpg 20040c5e7e381fff
# data/sand-cat\sd (5).jpg 041c7e3e7efcc0c0
# data/sand-cat\sd (50).jpg ffcbc1c1818181ff
# data/sand-cat\sd (51).jpg 043c3c787c787860
# data/sand-cat\sd (52).jpg 00f3ffff26865260
# data/sand-cat\sd (53).jpg e1c1f8f8f8f8f4e0
# data/sand-cat\sd (54).jpg fff700200002fbff
# data/sand-cat\sd (55).jpg 00001830707472f8
# data/sand-cat\sd (56).jpg fe9fdfc783112386
# data/sand-cat\sd (57).jpg f06606767d60c7ff
# data/sand-cat\sd (58).jpg 7f3cfc00080041ff
# data/sand-cat\sd (59).jpg 092fdfcf0c080800
# data/sand-cat\sd (6).jpg fffff81c3c1e0e0c
# data/sand-cat\sd (60).jpg 20383c7efbf3f3f7
# data/sand-cat\sd (61).jpg 277e3c3c3c3d19f9
# data/sand-cat\sd (62).jpg 00003c7879ffe7ff
# data/sand-cat\sd (63).jpg 80303c3e7be7ffff
# data/sand-cat\sd (64).jpg 00000b7ffcff8fcf
# data/sand-cat\sd (65).jpg 001d1d1e0d35e4e6
# data/sand-cat\sd (66).jpg 187c7f5f5f570e3e
# data/sand-cat\sd (67).jpg 475fe7c74707077f
# data/sand-cat\sd (68).jpg 037fffbf7c08e0e0
# data/sand-cat\sd (69).jpg 00040c0e7e199fff
# data/sand-cat\sd (7).jpg 0307e4e0c0871fff
# data/sand-cat\sd (70).jpg 383030303e2c3c10
# data/sand-cat\sd (71).jpg 3030383c1c1f3cfc
# data/sand-cat\sd (72).jpg 7c7efcf99bc20804
# data/sand-cat\sd (8).jpg 00303c1c9ef2faff
# data/sand-cat\sd (9).jpg 080c7c6cfcf0c0fc

# %%
hashes
# Out:
# {array([[ True,  True,  True,  True,  True,  True, False, False],
#         [ True,  True,  True, False,  True, False,  True,  True],
#         [ True,  True,  True, False, False, False, False, False],
#         [ True,  True,  True,  True, False, False, False, False],
#         [ True,  True,  True, False,  True, False, False, False],
#         [ True,  True,  True, False,  True, False, False, False],
#         [False, False, False, False, False, False, False, False],
#         [ True,  True,  True,  True,  True,  True,  True,  True]]): 'af (1).jpg',
#  array([[ True,  True,  True,  True, False, False, False, False],
#         [ True,  True,  True,  True,  True,  True, False, False],
#         [ True, False,  True,  True,  True, False, False, False],
#         [ True,  True,  True,  True,  True, False, False, False],
#         [ True,  True,  True,  True,  True, False, False, False],
#         [ True, False, False, False, False, False, False, False],
#         [False, False, False,  True, False, False, False, False],
#         [False, False,  True, False, False,  True,  True,  True]]): 'af (10).jpg',
#  array([[ True,  True,  True,  True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True,  True,  True,  True],
#         [ True,  True,  True, False, False, False, False,  True],
#         [ True,  True,  True,  True, False, False, False, False],
#         [ True,  True,  True,  True,  True, False, False,  True],
#         [ True,  True,  True, False,  True, False, False, False],
#         [ True,  True,  True, False,  True, False, False, False],
#         [False, False, False, False, False, False, False, False]]): 'af (11).jpg',
#  array([[False,  True,  True,  True, False, False, False,  True],
#         [False,  True,  True,  True, False,  True, False, False],
#         [ True, False,  True,  True,  True,  True,  True,  True],
#         [False, False, False,  True,  True,  True,  True,  True],
#         [False, False, False,  True,  True,  True, False, False],
#         [ True,  True,  True, False, False,  True,  True,  True],
#         [ True,  True, False, False, False,  True,  True,  True],
#         [False,  True, False, False, False,  True,  True,  True],
#         [False, False, False, False, False,  True,  True,  True],
#         [False, False, False, False, False,  True,  True,  True],
#         [False,  True,  True,  True,  True,  True,  True,  True]]): 'sd (67).jpg',
#  array([[False, False, False, False, False, False,  True,  True],
#         [False,  True,  True,  True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True,  True,  True,  True],
#         [ True, False,  True,  True,  True,  True,  True,  True],
#         [False,  True,  True,  True,  True,  True, False, False],
#         [False, False, False, False,  True, False, False, False],
#         [ True,  True,  True, False, False, False, False, False],
#         [ True,  True,  True, False, False, False, False, False]]): 'sd (68).jpg',
#  array([[False, False, False, False, False, False,  True,  True],
#         [False, False, False, False, False,  True,  True,  True],
#         [ True,  True,  True, False, False,  True, False, False],
#         [ True,  True,  True, False, False, False, False, False],
#         [ True,  True, False, False, False, False, False, False],
#         [ True, False, False, False, False,  True,  True,  True],
#         [False, False, False,  True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True,  True,  True,  True]]): 'sd (7).jpg',
#  array([[False, False,  True,  True,  True, False, False, False],
#         [False, False,  True,  True, False, False, False, False],
#         [False, False,  True,  True, False, False, False, False],
#         [False, False,  True,  True, False, False, False, False],
#         [False, False,  True,  True,  True,  True,  True, False],
#         [False, False,  True, False,  True,  True, False, False],
#         [False, False,  True,  True,  True,  True, False, False],
#         [False, False, False,  True, False, False, False, False]]): 'sd (70).jpg',
#  array([[False, False,  True,  True, False, False, False, False],
#         [False, False,  True,  True, False, False, False, False],
#         [False, False,  True,  True,  True, False, False, False],
#         [False, False,  True,  True,  True,  True, False, False],
#         [False, False, False,  True,  True,  True, False, False],
#         [False, False, False,  True,  True,  True,  True,  True],
#         [False, False,  True,  True,  True,  True, False, False],
#         [ True,  True,  True,  True,  True,  True, False, False]]): 'sd (71).jpg',
#  array([[False,  True,  True,  True,  True,  True, False, False],
#         [False,  True,  True,  True,  True,  True,  True, False],
#         [ True,  True,  True,  True,  True,  True, False, False],
#         [ True,  True,  True,  True,  True, False, False,  True],
#         [ True, False, False,  True,  True, False,  True,  True],
#         [ True,  True, False, False, False, False,  True, False],
#         [False, False, False, False,  True, False, False, False],
#         [False, False, False, False, False,  True, False, False]]): 'sd (72).jpg',
#  array([[False, False, False, False, False, False, False, False],
#         [False, False,  True,  True, False, False, False, False],
#         [False, False,  True,  True,  True,  True, False, False],
#         [False, False, False,  True,  True,  True, False, False],
#         [ True, False, False,  True,  True,  True,  True, False],
#         [ True,  True,  True,  True, False, False,  True, False],
#         [ True,  True,  True,  True,  True, False,  True, False],
#         [ True,  True,  True,  True,  True,  True,  True,  True]]): 'sd (8).jpg',
#  array([[False, False, False, False,  True, False, False, False],
#         [False, False, False, False,  True,  True, False, False],
#         [False,  True,  True,  True,  True,  True, False, False],
#         [False,  True,  True, False,  True,  True, False, False],
#         [ True,  True,  True,  True,  True,  True, False, False],
#         [ True,  True,  True,  True, False, False, False, False],
#         [ True,  True, False, False, False, False, False, False],
#         [ True,  True,  True,  True,  True,  True, False, False]]): 'sd (9).jpg'}

# %% [markdown]
# ### Problem 3. Loading a model (2 points)
# Find a suitable, trained convolutional neural network classifier. I recommend `ResNet50` as it's small enough to run well on any machine and powerful enough to make reasonable predictions. Most ready-made classifiers have been trained for 1000 classes.
#
# You'll need to install libraries and possibly tinker with configurations for this task. When you're done, display the total number of layers and the total number of parameters. For ResNet50, you should expect around 50 layers and 25M parameters.

# %% [markdown]
# ### Problem 4. Prepare the images (1 point)
# You'll need to prepare the images for passing to the model. To do so, they have to be resized to the same dimensions. Most available models have a specific requirement for sizes. You may need to do additional preprocessing, depending on the model requirements. These requirements should be easily available in the model documentation.

# %% [markdown]
# ### Problem 5. Load the images efficiently (1 point)
# Now that you've seen how to prepare the images for passing to the model... find a way to do it efficiently. Instead of loading the entire dataset in the RAM, read the images in batches (e.g. 4 images at a time). The goal is to read these, preprocess them, maybe save the preprocessed results in RAM.
#
# If you've already done this in one of the previous problems, just skip this one. You'll get your point for it.
#
# \* Even better, save the preprocessed image arrays (they will not be valid .jpg file) as separate files, so you can load them "lazily" in the following steps. This is a very common optimization to work with large datasets.

# %% [markdown]
# ### Problem 6. Predictions (1 point)
# Finally, you're ready to get into the meat of the problem. Obtain predictions from your model and evaluate them. This will likely involve manual work to decide how the returned classes relate to the original ones.
#
# Create a [confusion matrix](https://en.wikipedia.org/wiki/Confusion_matrix) to evaluate the classification.

# %% [markdown]
# ### Problem 7. Grayscale (1 point)
# Converting the images to grayscale should affect the classification negatively, as we lose some of the color information.
#
# Find a way to preprocess the images to grayscale (using what you already have in Problem 4 and 5), pass them to the model, and compare the classification results to the previous ones.

# %% [markdown]
# ### Problem 8. Deep image features (1 point)
# Find a way to extract one-dimensional vectors (features) for each (non-grayscale) image, using your model. This is typically done by "short-circuiting" the model output to be an intermediate layer, while keeping the input the same.
#
# In case the outputs (also called feature maps) have different shapes, you can flatten them in different ways. Try to not create huge vectors; the goal is to have a relatively short sequence of numbers which describes each image.
#
# You may find a tutorial like [this](https://towardsdatascience.com/exploring-feature-extraction-with-cnns-345125cefc9a) pretty useful but note your implementation will depend on what model (and framework) you've decided to use.
#
# It's a good idea to save these as one or more files, so you'll spare yourself a ton of preprocessing.

# %% [markdown]
# ### Problem 9. Putting deep image features to use (1 points)
# Try to find similar images, using a similarity metric on the features you got in the previous problem. Two good metrics are `mean squared error` and `cosine similarity`. How do they work? Can you spot images that look too similar? Can you explain why?
#
# \* If we were to take Fourier features (in a similar manner, these should be a vector of about the same length), how do they compare to the deep features; i.e., which features are better to "catch" similar images?

# %% [markdown]
# ### * Problem 10. Explore, predict, and evaluate further
# You can do a ton of things here, at your desire. For example, how does masking different areas of the image affect classification - a method known as **saliency map** ([info](https://en.wikipedia.org/wiki/Saliency_map))? Can we detect objects? Can we significantly reduce the number of features (keeping the quality) that we get? Can we reliably train a model to predict our own classes? We'll look into these in detail in the future.
